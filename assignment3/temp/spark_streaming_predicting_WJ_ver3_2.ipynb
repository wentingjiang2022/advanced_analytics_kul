# %%
import threading

# Helper thread to avoid the Spark StreamingContext from blocking Jupyter
        
class StreamingThread(threading.Thread):
    def __init__(self, ssc):

        super().__init__()
        self.ssc = ssc
    def run(self):
        self.ssc.start()
        self.ssc.awaitTermination()
    def stop(self):
        print('----- Stopping... this may take a few seconds -----')
        self.ssc.stop(stopSparkContext=False, stopGraceFully=True)

# %%
sc
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.0.171:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# # build model

# %%
from pyspark.streaming import StreamingContext
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.ml.feature import Tokenizer, StopWordsRemover, CountVectorizer, IDF, StringIndexer, HashingTF
from pyspark.ml.classification import LogisticRegression, RandomForestClassifier
from pyspark.ml import Pipeline
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.sql.functions import expr
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.ml.feature import Word2Vec
from pyspark.ml import Pipeline
from pyspark.sql.functions import split, rand
from pyspark.sql.types import StructType, StructField, StringType, DoubleType

file_location="reviews.csv"

# %%
# create a SparkSession 
spark = SparkSession.builder \
    .appName("assignment 3") \
    .config("spark.driver.memory", "2g") \
    .config("spark.executor.memory", "2g") \
    .config("spark.driver.cores", "2") \
    .getOrCreate()

# %%
# read csv

text_df = spark.read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .option("multiline", "true") \
    .option("delimiter", "\t") \
    .csv(file_location)

text_df = text_df.select(col('review_text'), col('label'))
text_df.show()
# Out:
# +--------------------+-----+
# |         review_text|label|
# +--------------------+-----+
# |i can confirm tha...|  1.0|
# |Really good game,...|  1.0|
# |Its not finished ...|  1.0|
# |Hey. It's really ...|  1.0|
# |          Fun so far|  1.0|
# |I'd rather play W...|  0.0|
# |I have been playi...|  1.0|
# |Nice game! Loads ...|  1.0|
# |All hail NA serve...|  1.0|
# |enjoying it so fa...|  1.0|
# |This game came as...|  1.0|
# |         Great fun  |  1.0|
# |Fantastic consept...|  1.0|
# |You know the game...|  1.0|
# |EDIT: My issues h...|  1.0|
# |AMAZIIIIIIIIIIING...|  1.0|
# |In its current st...|  0.0|
# |Играю в Калибр го...|  1.0|
# |Secret Word: Prou...|  1.0|
# |Fated Word: Death...|  1.0|
# +--------------------+-----+
# only showing top 20 rows

# %%
# Remove duplicate rows
text_df = text_df.dropDuplicates()
# Remove rows with missing values
text_df = text_df.na.drop()

# %%
text_df.select("label").distinct().show()
# Out:
# +--------------------+
# |               label|
# +--------------------+
# |                 1.0|
# |                 0.0|
# |It's been at leas...|
# |[td]✔️ Exciting p...|
# |- I literally onl...|
# +--------------------+

# %%
# Remove rows with unexpected labels
text_df = text_df.filter((col("label") == 1.0) | (col("label") == 0.0))
print("Number of rows after filtering: ", text_df.count())
print("Number of rows after filtering with 1 labelled: ", text_df.filter(col("label") == 1.0).count())
print("Number of rows after filtering with 0 labelled: ", text_df.filter(col("label") == 0.0).count())
# Out:
# Number of rows after filtering:  36913
# Number of rows after filtering with 1 labelled:  29406
# Number of rows after filtering with 0 labelled:  7507

# %%
# make balanced dataset
text_df_0 = text_df.filter(col("label") == 0.0)  
text_df_1 = text_df.filter(col("label") == 1.0) 
sampled_text_df_1 = text_df_1.orderBy(rand()).limit(text_df_0.count())
balance_text_df = text_df_0.union(sampled_text_df_1)
print("1 labelled: ", balance_text_df.filter(col("label") == 1.0).count())
print("0 labelled: ", balance_text_df.filter(col("label") == 0.0).count())
# Out:
# 1 labelled:  7507
# 0 labelled:  7507

# %%
# Split data set
train_data, test_data = balance_text_df.randomSplit([0.8, 0.2], seed=7)

# %%
# preprocess the data
tokenizer = Tokenizer(inputCol="review_text", outputCol="words")
stopwords_remover = StopWordsRemover(inputCol="words", outputCol="filtered_words", locale="en_US")
count_vectorizer = CountVectorizer(inputCol="filtered_words", outputCol="raw_features")
idf = IDF(inputCol="raw_features", outputCol="features")
string_indexer = StringIndexer(inputCol="label", outputCol="label_index")

# create model
lr = LogisticRegression(featuresCol="features", labelCol="label_index")

# %%
# define params grid
param_grid = ParamGridBuilder() \
   .addGrid(count_vectorizer.vocabSize, [1000, 5000]) \
   .addGrid(lr.regParam, [0.01, 0.1]) \
   .addGrid(lr.elasticNetParam, [0.0, 0.5, 1.0]) \
   .build()

# define the evaluator
evaluator = MulticlassClassificationEvaluator(labelCol="label_index", predictionCol="prediction")

# %%
# create pipeline
pipeline = Pipeline(stages=[tokenizer, stopwords_remover, count_vectorizer, idf, string_indexer, lr])

# define the cross-validator
cv = CrossValidator(estimator=pipeline, estimatorParamMaps=param_grid, evaluator=evaluator, numFolds=3)

# fit pipeline to the training data
cv_model = cv.fit(train_data)

# make predictions on the test data
predictions = cv_model.transform(test_data)

# %%
evaluator = MulticlassClassificationEvaluator(labelCol="label_index", predictionCol="prediction")

# Calculate accuracy
accuracy = evaluator.evaluate(predictions, {evaluator.metricName: "accuracy"})

# Calculate F1 score
f1_score = evaluator.evaluate(predictions, {evaluator.metricName: "f1"})

# Calculate recall
recall = evaluator.evaluate(predictions, {evaluator.metricName: "weightedRecall"})

# Calculate precision
precision = evaluator.evaluate(predictions, {evaluator.metricName: "weightedPrecision"})

print("Accuracy: {:.4f}".format(accuracy))
print("F1 score: {:.4f}".format(f1_score))
print("Recall: {:.4f}".format(recall))
print("Precision: {:.4f}".format(precision))
# Out:
# Accuracy: 0.8234
# F1 score: 0.8227
# Recall: 0.8234
# Precision: 0.8303

# %%
from pyspark.mllib.evaluation import MulticlassMetrics

# Convert the predictions and labels to an RDD
predictionAndLabels = predictions.select("prediction", "label_index").rdd.map(lambda r: (r[0], r[1]))

# Instantiate a MulticlassMetrics object
metrics = MulticlassMetrics(predictionAndLabels)

# Get the confusion matrix as a NumPy array
confusion_matrix = metrics.confusionMatrix().toArray()

# Print the confusion matrix
print("Confusion matrix:")
print(confusion_matrix)
# Out:
# C:\spark\spark-3.3.2-bin-hadoop2\python\pyspark\sql\context.py:157: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# Confusion matrix:
# [[1324.  160.]
#  [ 372. 1156.]]

# %%
# Get the best model from the cross-validation process
best_model = cv_model.bestModel

# Save the my_model
best_model.save("my_logistic_regression2")

# %%
from pyspark.mllib.evaluation import MulticlassMetrics

# %%
from pyspark.ml import PipelineModel
globals()['models_loaded'] = False
globals()['my_model'] = None

global results
results = []

def process(time, rdd):
    if rdd.isEmpty():
        return
    
    print("========= %s =========" % str(time))
    
    # Convert to data frame
    df = spark.read.json(rdd)
    df = df.withColumn("label", col("label").cast("float"))
    df.show()
    
    # Load in the model if not yet loaded:
    if not globals()['models_loaded']:
        # load in your models here
        globals()['my_model'] = PipelineModel.load('my_logistic_regression')
        globals()['models_loaded'] = True
        
    # And then predict using the loaded model (uncomment below):
    
    df_result = globals()['my_model'].transform(df)
    df_result.select('label', 'review_text', 'prediction','probability', 'label_index').show()
    
    collected_results = df_result.select('prediction', 'label_index').collect()
    results.extend(collected_results)
    
    # If we have collected 10 results, show the data and clear the results list
    display_results(results)


def display_results(results):
    result_df = spark.createDataFrame(results)
    predictionAndLabels = result_df.select("prediction", "label_index").rdd.map(lambda r: (r[0], r[1]))
    metrics = MulticlassMetrics(predictionAndLabels)
    confusion_matrix = metrics.confusionMatrix().toArray()
    print("Confusion matrix:")
    print(confusion_matrix)

# %%
ssc = StreamingContext(sc, 10)

# %%
lines = ssc.socketTextStream("seppe.net", 7778)
lines.foreachRDD(process)

# %%
ssc_t = StreamingThread(ssc)
ssc_t.start()
# Out:
# ========= 2023-05-26 14:41:30 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1938800|  1.0|139011455|What was good:\n-...|
# |1938800|  0.0|139010594|An utter waste of...|
# |2146070|  1.0|139010683|[quote][b]Check o...|
# |2406990|  0.0|139010130|lidl version of S...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|What was good:\n-...|       0.0|[0.78293282055781...|        0.0|
# |  0.0|An utter waste of...|       1.0|[0.01587355745218...|        1.0|
# |  1.0|[quote][b]Check o...|       0.0|[0.65220338000149...|        0.0|
# |  0.0|lidl version of S...|       0.0|[0.88321833922714...|        1.0|
# +-----+--------------------+----------+--------------------+-----------+
# C:\spark\spark-3.3.2-bin-hadoop2\python\pyspark\sql\context.py:157: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# Confusion matrix:
# [[2. 0.]
#  [1. 1.]]
# ========= 2023-05-26 14:41:40 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# | 669330|  1.0|139012214|If you like strat...|
# |2369390|  1.0|139013132|This fun game som...|
# |2369390|  1.0|139012787| I far-cri evryti...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|If you like strat...|       0.0|[0.94703637375330...|        0.0|
# |  1.0|This fun game som...|       0.0|[0.84246787984123...|        0.0|
# |  1.0| I far-cri evryti...|       0.0|[0.79337675488982...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[5. 0.]
#  [1. 1.]]
# ========= 2023-05-26 14:41:50 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |2369390|  1.0|139012073|                  <3|
# |2369390|  1.0|139011025|                Coño|
# |2367760|  1.0|139013260|I am enjoying thi...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|                  <3|       0.0|[0.92036380778704...|        0.0|
# |  1.0|                Coño|       0.0|[0.86618000513816...|        0.0|
# |  1.0|I am enjoying thi...|       0.0|[0.93933636051389...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[8. 0.]
#  [1. 1.]]
# ========= 2023-05-26 14:42:20 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |2375160|  1.0|139011788|Love temp of the ...|
# |1268750|  1.0|139013622|The only good bug...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|Love temp of the ...|       0.0|[0.91726990373576...|        0.0|
# |  1.0|The only good bug...|       0.0|[0.91669924608775...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[10.  0.]
#  [ 1.  1.]]
# ========= 2023-05-26 14:42:30 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1268750|  1.0|139013254|shoot 300 rounds ...|
# |1268750|  1.0|139013020|game is great fun...|
# |1268750|  1.0|139012987|THE ONLY GOOD BUG...|
# |1268750|  1.0|139012744|Awesome game with...|
# |1268750|  1.0|139012194|only gud bug is a...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0
|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|I think this game...|       0.0|[0.98803691548077...|        0.0|
# |  0.0|AI gets stuck som...|       1.0|[0.08835744868803...|        1.0|
# |  0.0|needs work for st...|       0.0|[0.78120369365297...|        1.0|
# |  0.0|After Us no reinv...|       0.0|[0.99996724718798...|        1.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[31.  0.]
#  [ 3.  3.]]
# ========= 2023-05-26 14:44:10 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1608230|  1.0|139013008|if you love games...|
# |1608230|  1.0|139012177|Pros: -Looks real...|
# |1649010|  1.0|139013909|Pretty fun game s...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|if you love games...|       0.0|[0.99877891342975...|        0.0|
# |  1.0|Pros: -Looks real...|       0.0|[0.99396118912870...|        0.0|
# |  1.0|Pretty fun game s...|       0.0|[0.99984275526583...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[34.  0.]
#  [ 3.  3.]]
# ========= 2023-05-26 14:44:20 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1972640|  1.0|139012009|Fans of visual no...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|Fans of visual no...|       0.0|[0.99998900693275...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[35.  0.]
#  [ 3.  3.]]
# ========= 2023-05-26 14:44:30 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |2005010|  1.0|139013842|This is the first...|
# |2005010|  1.0|139013753|Kill heretics?\nY...|
# |2005010|  1.0|139013730|[h1]By the Empero...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|This is the first...|       1.0|[0.18663942898495...|        0.0|
# |  1.0|Kill heretics?\nY...|       0.0|[0.85294599328470...|        0.0|
# |  1.0|[h1]By the Empero...|       0.0|[0.99753257531649...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[37.  1.]
#  [ 3.  3.]]
# ========= 2023-05-26 14:44:40 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |2005010|  1.0|139013729|Great game, Emper...|
# |2005010|  1.0|139013646|An incredibly goo...|
# |2005010|  1.0|139013556|        Better doom.|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|Great game, Emper...|       0.0|[0.99956712213053...|        0.0|
# |  1.0|An incredibly goo...|       0.0|[0.88610536486985...|        0.0|
# |  1.0|        Better doom.|       0.0|[0.89730751147718...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[40.  1.]
#  [ 3.  3.]]
# ========= 2023-05-26 14:44:50 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |2005010|  1.0|139013440|                 Yes|
# |2005010|  1.0|139013034|Fantastic game, o...|
# |2005010|  1.0|139012861|Absolutely fantas...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|                 Yes|       0.0|[0.93185261752941...|        0.0|
# |  1.0|Fantastic game, o...|       0.0|[0.95009215368311...|        0.0|
# |  1.0|Absolutely fantas...|       0.0|[0.89015852576396...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[43.  1.]
#  [ 3.  3.]]
# ========= 2023-05-26 14:45:40 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |2218750|  1.0|139013696|great game been p...|
# |2218750|  1.0|139012222|           Very fun.|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|great game been p...|       0.0|[0.92307804866434...|        0.0|
# |  1.0|           Very fun.|       0.0|[0.91881637787308...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[45.  1.]
#  [ 3.  3.]]
# ========= 2023-05-26 14:46:30 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |2109020|  0.0|139013352|I see this is a o...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  0.0|I see this is a o...|       1.0|[0.09335653673162...|        1.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[45.  1.]
#  [ 3.  4.]]
# ========= 2023-05-26 14:48:40 =========
# +-------+-----+---------+-----------+
# | app_id|label|review_id|review_text|
# +-------+-----+---------+-----------+
# |2235240|  1.0|139013511|      Good.|
# +-------+-----+---------+-----------+
#
# +-----+-----------+----------+--------------------+-----------+
# |label|review_text|prediction|         probability|label_index|
# +-----+-----------+----------+--------------------+-----------+
# |  1.0|      Good.|       0.0|[0.92796777303279...|        0.0|
# +-----+-----------+----------+--------------------+-----------+
# Confusion matrix:
# [[46.  1.]
#  [ 3.  4.]]
# ========= 2023-05-26 14:48:50 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |
|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  0.0|      i cant open it|       0.0|[0.72993371304541...|        1.0|
# |  1.0|Beautiful game\nB...|       0.0|[0.97197257480196...|        0.0|
# |  1.0|This is a game th...|       1.0|[0.01225466899330...|        0.0|
# |  1.0|Cultivation: A Re...|       0.0|[0.78817630664535...|        0.0|
# |  0.0|Can not launch th...|       0.0|[0.87832290723838...|        1.0|
# |  1.0|exciting and rela...|       0.0|[0.92294671957496...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[74.  2.]
#  [10. 11.]]
# ========= 2023-05-26 14:54:30 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1468810|  1.0|138660136|I already know mo...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|I already know mo...|       0.0|[0.52918393572527...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[75.  2.]
#  [10. 11.]]
# ========= 2023-05-26 14:54:50 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1468810|  1.0|127439040|If what you want ...|
# |1468810|  1.0|127422463|           good game|
# |1468810|  1.0|127422449|If you know what ...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|If what you want ...|       0.0|[0.96651502768710...|        0.0|
# |  1.0|           good game|       0.0|[0.91739395568935...|        0.0|
# |  1.0|If you know what ...|       0.0|[0.85423195915360...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[78.  2.]
#  [10. 11.]]
# ========= 2023-05-26 14:55:00 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1468810|  1.0|127374443|I have no clue wh...|
# |1468810|  1.0|127368967|If you love Chine...|
# |1468810|  1.0|127358493|                Nice|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|I have no clue wh...|       0.0|[0.54761514905206...|        0.0|
# |  1.0|If you love Chine...|       0.0|[0.80483150571909...|        0.0|
# |  1.0|                Nice|       0.0|[0.91228258299323...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[81.  2.]
#  [10. 11.]]
# ========= 2023-05-26 14:55:10 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1468810|  1.0|127167118|This game is amaz...|
# |1468810|  0.0|127033540|            BAD GAME|
# |1468810|  1.0|126914224|Fun gameplay loop...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|This game is amaz...|       0.0|[0.99990307998686...|        0.0|
# |  0.0|            BAD GAME|       0.0|[0.73647491906673...|        1.0|
# |  1.0|Fun gameplay loop...|       0.0|[0.68169675294078...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[83.  2.]
#  [11. 11.]]
# ========= 2023-05-26 14:55:20 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1468810|  1.0|126894567|Fun gameplay, esp...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|Fun gameplay, esp...|       0.0|[0.88160596601616...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[84.  2.]
#  [11. 11.]]
# ========= 2023-05-26 14:55:40 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1468810|  1.0|118667590| \n\ndelete versi...|
# |1468810|  1.0|118634027|           good game|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0| \n\ndelete versi...|       1.0|[0.24788421706800...|        0.0|
# |  1.0|           good game|       0.0|[0.91739395568935...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[85.  3.]
#  [11. 11.]]
# ========= 2023-05-26 14:55:50 =========
# +-------+-----+---------+-----------------------+
# | app_id|label|review_id|            review_text|
# +-------+-----+---------+-----------------------+
# |1468810|  1.0|118591093|   game gets a littl...|
# |1468810|  0.0|118578599|   Game refuse to bo...|
# |1468810|  0.0|118523871|无法启动，不支持win11？|
# |1468810|  1.0|118504013|   The game is still...|
# +-------+-----+---------+-----------------------+
#
# +-----+-----------------------+----------+--------------------+-----------+
# |label|            review_text|prediction|         probability|label_index|
# +-----+-----------------------+----------+--------------------+-----------+
# |  1.0|   game gets a littl...|       0.0|[0.93814582588150...|        0.0|
# |  0.0|   Game refuse to bo...|       0.0|[0.97157078603491...|        1.0|
# |  0.0|无法启动，不支持win11？|       0.0|[0.86618000513816...|        1.0|
# |  1.0|   The game is still...|       0.0|[0.75567061868331...|        0.0|
# +-----+-----------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[87.  3.]
#  [13. 11.]]
# ========= 2023-05-26 14:56:00 =========
# +-------+-----+---------+-----------+
# | app_id|label|review_id|review_text|
# +-------+-----+---------+-----------+
# |1468810|  1.0|118497541|       Good|
# |1468810|  0.0|118493565|   吃相难看|
# |1468810|  0.0|118478644|  shit game|
# +-------+-----+---------+-----------+
#
# +-----+-----------+----------+--------------------+-----------+
# |label|review_text|prediction|         probability|label_index|
# +-----+-----------+----------+--------------------+-----------+
# |  1.0|       Good|       0.0|[0.91943148446649...|        0.0|
# |  0.0|   吃相难看|       0.0|[0.86618000513816...|        1.0|
# |  0.0|  shit game|       0.0|[0.62542383523686...|        1.0|
# +-----+-----------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[88.  3.]
#  [15. 11.]]
# ========= 2023-05-26 14:56:10 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1468810|  1.0|118471492|Amazing game, goo...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|Amazing game, goo...|       0.0|[0.92836366204511...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[89.  3.]
#  [15. 11.]]
# ========= 2023-05-26 14:56:30 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1468810|  0.0|114681045|Do not buy this g...|
# |1468810|  0.0|114680698|        创意工坊呢？|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  0.0|Do not buy this g...|       0.0|[0.90500462332499...|        1.0|
# |  0.0|        创意工坊呢？|       0.0|[0.86618000513816...|        1.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[89.  3.]
#  [17. 11.]]
# ========= 2023-05-26 14:56:40 =========
# +-------+-----+---------+------------------------------+
# | app_id|label|review_id|                   review_text|
# +-------+-----+---------+------------------------------+
# |1468810|  1.0|114680567|          I don't care abou...|
# |1468810|  1.0|114677578|          too many troll votes|
# |1468810|  0.0|114675077|我买这个游戏的时不知道我是傻逼|
# +-------+-----+---------+------------------------------+
#
# +-----+------------------------------+----------+--------------------+-----------+
# |label|                   review_text|prediction|         probability|label_index|
# +-----+------------------------------+----------+--------------------+-----------+
# |  1.0|          I don't care abou...|       0.0|[0.80545184799550...|        0.0|
# |  1.0|          too many troll votes|       0.0|[0.84777918489534...|        0.0|
# |  0.0|我买这个游戏的时不知道我是傻逼|       0.0|[0.86618000513816...|        1.0|
# +-----+------------------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[91.  3.]
#  [18. 11.]]
# ========= 2023-05-26 14:56:50 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1468810|  1.0|114670557|Base game = Amazi...|
# |1468810|  0.0|114663812|       not recommend|
# |1468810|  0.0|114663408|Well be happy to ...|
# |1468810|  0.0|114662419|Disappointed by t...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|Base game = Amazi...|       0.0|[0.99685472930480...|        0.0|
# |  0.0|       not recommend|       0.0|[0.81080351506150...|        1.0|
# |  0.0|Well be happy to ...|       0.0|[0.94947824366144...|        1.0|
# |  0.0|Disappointed by t...|       1.0|[0.47988091737766...|        1.0|
# +-----+--------------------+----------+--------------------+-----------+
# Confusion matrix:
# [[92.  3.]
#  [20. 12.]]
# ========= 2023-05-26 14:57:00 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1468810|  0.0|114657619|Suspected of seri...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  0.0|Suspected of seri...|       1.0|[0.21029705122662...|        1.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[92.  3.]
#  [20. 13.]]
# ========= 2023-05-26 14:57:10 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1468810|  1.0|111122279|A great game, it'...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|A great game, it'...|       0.0|[0.98301487726911...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[93.  3.]
#  [20. 13.]]
# ========= 2023-05-26 14:57:20 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1468810|  1.0|111117239|As a Xianxia fana...|
# |1468810|  1.0|111070251|For those that li...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|As a Xianxia fana...|       0.0|[0.99987251135262...|        0.0|
# |  1.0|For those that li...|       0.0|[0.99157179354729...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[95.  3.]
#  [20. 13.]]
# ========= 2023-05-26 14:57:30 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1468810|  1.0|110975097|               Good.|
# |1468810|  1.0|110909173|its a very in-dep...|
# |1468810|  1.0|110907245|Constantly get nu...|
# |1468810|  1.0|110874539|      love this game|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|               Good.|       0.0|[0.92796777303279...|        0.0|
# |  1.0|its a very in-dep...|       0.0|[0.95636242151907...|        0.0|
# |  1.0|Constantly get nu...|       0.0|[0.78802019375095...|        0.0|
# |  1.0|      love this game|       0.0|[0.91726990373576...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[99.  3.]
#  [20. 13.]]
# ========= 2023-05-26 14:57:40 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1468810|  1.0|110837569|Dont play chaos ,...|
# |1468810|  1.0|110799025|Very cool game, i...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|Dont play chaos ,...|       0.0|[0.93952043299845...|        0.0|
# |  1.0|Very cool game, i...|       0.0|[0.91837254529047...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[101.   3.]
#  [ 20.  13.]]
# ========= 2023-05-26 14:57:50 =========
# +-------+-----+---------+-------------------------------------+
# | app_id|label|review_id|                          review_text|
# +-------+-----+---------+-------------------------------------+
# |1468810|  1.0|110788850|宗门任务杀了几个人，换月的时候就胆...|
# +-------+-----+---------+-------------------------------------+
#
# +-----+-------------------------------------+----------+--------------------+-----------+
# |label|                          review_text|prediction|         probability|label_index|
# +-----+-------------------------------------+----------+--------------------+-----------+
# ...
# [[106.   3.]
#  [ 21.  13.]]
# ========= 2023-05-26 14:58:40 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1468810|  1.0|104936045|    Unique gameplay.|
# |1468810|  1.0|104930815|Cultivation is po...|
# |1468810|  1.0|104904609|I can confirm tha...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|    Unique gameplay.|       0.0|[0.91755897127604...|        0.0|
# |  1.0|Cultivation is po...|       0.0|[0.86618000513816...|        0.0|
# |  1.0|I can confirm tha...|       0.0|[0.53919890215117...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[109.   3.]
#  [ 21.  13.]]
# ========= 2023-05-26 14:58:50 =========
# +-------+-----+---------+-------------------+
# | app_id|label|review_id|        review_text|
# +-------+-----+---------+-------------------+
# |1468810|  1.0|104882570|Time to cultivate !|
# |1468810|  1.0|104873815|       just amazing|
# +-------+-----+---------+-------------------+
#
# +-----+-------------------+----------+--------------------+-----------+
# |label|        review_text|prediction|         probability|label_index|
# +-----+-------------------+----------+--------------------+-----------+
# |  1.0|Time to cultivate !|       0.0|[0.89609691418735...|        0.0|
# |  1.0|       just amazing|       0.0|[0.95228177172600...|        0.0|
# +-----+-------------------+----------+--------------------+-----------+
# Confusion matrix:
# [[111.   3.]
#  [ 21.  13.]]
# ========= 2023-05-26 14:59:00 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1468810|  1.0| 99488313|Really love this ...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|Really love this ...|       0.0|[0.99165776033389...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[112.   3.]
#  [ 21.  13.]]
# ========= 2023-05-26 14:59:10 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1468810|  1.0| 99486999|This game is a MA...|
# |1468810|  1.0| 99486365|1) Finally made i...|
# |1468810|  0.0| 99482491|It's really fucki...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|This game is a MA...|       0.0|[0.99938369254277...|        0.0|
# |  1.0|1) Finally made i...|       0.0|[0.99457724412925...|        0.0|
# |  0.0|It's really fucki...|       1.0|[0.02497082739599...|        1.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[114.   3.]
#  [ 21.  14.]]
# ========= 2023-05-26 14:59:20 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1468810|  1.0| 99479834|         Great game.|
# |1468810|  1.0| 99478817|              good\n|
# |1468810|  1.0| 99477086|30 hrs early was ...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|         Great game.|       0.0|[0.93448749990112...|        0.0|
# |  1.0|              good\n|       0.0|[0.91943148446649...|        0.0|
# |  1.0|30 hrs early was ...|       0.0|[0.82098488799341...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[117.   3.]
#  [ 21.  14.]]
# ========= 2023-05-26 14:59:30 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1468810|  1.0| 99465740|         great game!|
# |1468810|  1.0| 99458677|let me tell you h...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|         great game!|       0.0|[0.96970514154418...|        0.0|
# |  1.0|let me tell you h...|       0.0|[0.99290452950532...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[119.   3.]
#  [ 21.  14.]]
# ========= 2023-05-26 14:59:40 =========
# +-------+-----+---------+-----------+
# | app_id|label|review_id|review_text|
# +-------+-----+---------+-----------+
# |1468810|  1.0| 99456667|      great|
# +-------+-----+---------+-----------+
#
# +-----+-----------+----------+--------------------+-----------+
# |label|review_text|prediction|         probability|label_index|
# +-----+-----------+----------+--------------------+-----------+
# |  1.0|      great|       0.0|[0.92768697604074...|        0.0|
# +-----+-----------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[120.   3.]
#  [ 21.  14.]]
# ========= 2023-05-26 14:59:50 =========
# +-------+-----+---------+-----------+
# | app_id|label|review_id|review_text|
# +-------+-----+---------+-----------+
# |1468810|  1.0| 95658837|       good|
# |1468810|  0.0| 95656158|         NO|
# +-------+-----+---------+-----------+
#
# +-----+-----------+----------+--------------------+-----------+
# |label|review_text|prediction|         probability|label_index|
# +-----+-----------+----------+--------------------+-----------+
# |  1.0|       good|       0.0|[0.91943148446649...|        0.0|
# |  0.0|         NO|       0.0|[0.86618000513816...|        1.0|
# +-----+-----------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[121.   3.]
#  [ 22.  14.]]
# ========= 2023-05-26 15:00:00 =========
# +-------+-----+---------+------------------------------+
# | app_id|label|review_id|                   review_text|
# +-------+-----+---------+------------------------------+
# |1468810|  0.0| 95638328| steam第一个差评，一个mod制...|
# |1468810|  0.0| 95605078|             Update so late...|
# |1468810|  1.0| 95542336|太多玩法待开发，非常期待正式版|
# +-------+-----+---------+------------------------------+
#
# +-----+------------------------------+----------+--------------------+-----------+
# |label|                   review_text|prediction|         probability|label_index|
# +-----+------------------------------+----------+--------------------+-----------+
# |  0.0| steam第一个差评，一个mod制...|       0.0|[0.86618000513816...|        1.0|
# |  0.0|             Update so late...|       0.0|[0.84465788036697...|        1.0|
# |  1.0|太多玩法待开发，非常期待正式版|       0.0|[0.86618000513816...|        0.0|
# +-----+------------------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[122.   3.]
#  [ 24.  14.]]
# ========= 2023-05-26 15:00:10 =========
# +-------+-----+---------+-------------------------------------+
# | app_id|label|review_id|                          review_text|
# +-------+-----+---------+-------------------------------------+
# |1468810|  1.0| 95539741|                  must  have  for fan|
# |1468810|  1.0| 95533529|                 A nice RPG game w...|
# |1468810|  1.0| 95511610|水准以上的游戏，因为还有一些东西没...|
# |1468810|  1.0| 95486929|                            good game|
# +-------+-----+---------+-------------------------------------+
#
# +-----+-------------------------------------+----------+--------------------+-----------+
# |label|                          review_text|prediction|         probability|label_index|
# +-----+-------------------------------------+----------+--------------------+-----------+
# |  1.0|                  must  have  for fan|       0.0|[0.90162614530322...|        0.0|
# |  1.0|                 A nice RPG game w...|       0.0|[0.98742448734096...|        0.0|
# |  1.0|水准以上的游戏，因为还有一些东西没...|       0.0|[0.86618000513816...|        0.0|
# |  1.0|                            good game|       0.0|[0.91739395568935...|        0.0|
# +-----+-------------------------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[126.   3.]
#  [ 24.  14.]]
# ========= 2023-05-26 15:00:20 =========
# +-------+-----+---------+----------------------------+
# | app_id|label|review_id|                 review_text|
# +-------+-----+---------+----------------------------+
# |1468810|  0.0| 95476643|edit:我是傻逼\n\n这更新速...|
# +-------+-----+---------+----------------------------+
#
# +-----+----------------------------+----------+--------------------+-----------+
# |label|                 review_text|prediction|         probability|label_index|
# +-----+----------------------------+----------+--------------------+-----------+
# |  0.0|edit:我是傻逼\n\n这更新速...|       0.0|[0.86615215774838...|        1.0|
# +-----+----------------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[126.   3.]
#  [ 25.  14.]]
# ========= 2023-05-26 15:00:40 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1468810|  1.0| 87944936|                   h|
# |1468810|  1.0| 87944588|a very fun game t...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|                   h|       0.0|[0.88116197867334...|        0.0|
# |  1.0|a very fun game t...|       0.0|[0.85393332770668...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
# Confusion matrix:
# [[128.   3.]
#  [ 25.  14.]]
# ========= 2023-05-26 15:00:50 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1468810|  1.0| 87933996|Only very few tim...|
# |1468810|  1.0| 87929546|Awesome graphic a...|
# |1468810|  1.0| 87926102|           Good game|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|Only very few tim...|       0.0|[0.94928422336487...|        0.0|
# |  1.0|Awesome graphic a...|       0.0|[0.96259243551428...|        0.0|
# |  1.0|           Good game|       0.0|[0.91739395568935...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[131.   3.]
#  [ 25.  14.]]
# ========= 2023-05-26 15:01:00 =========
# +-------+-----+---------+--------------------------------------+
# | app_id|label|review_id|                           review_text|
# +-------+-----+---------+--------------------------------------+
# |1468810|  1.0| 87911669|出乎意料的好玩以及完全停不下来的体验。|
# |1468810|  1.0| 87896702|                                  nice|
# |1468810|  1.0| 87889064|                         Time machine!|
# |1468810|  1.0| 87880597|           有趣, 但到結晶後玩不下去了.|
# |1468810|  1.0| 87879536|   太社会了。\n玩雷系，差点被自己劈...|
# +-------+-----+---------+--------------------------------------+
#
# +-----+--------------------------------------+----------+--------------------+-----------+
# |label|                           review_text|prediction|         probability|label_index|
# +-----+--------------------------------------+----------+--------------------+-----------+
# |  1.0|出乎意料的好玩以及完全停不下来的体验。|       0.0|[0.86618000513816...|        0.0|
# |  1.0|                                  nice|       0.0|[0.91228258299323...|        0.0|
# |  1.0|                         Time machine!|       0.0|[0.87923252057813...|        0.0|
# |  1.0|           有趣, 但到結晶後玩不下去了.|       0.0|[0.86618000513816...|        0.0|
# |  1.0|   太社会了。\n玩雷系，差点被自己劈...|       0.0|[0.86618000513816...|        0.0|
# +-----+--------------------------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[136.   3.]
#  [ 25.  14.]]
# ========= 2023-05-26 15:01:30 =========
# +-------+-----+---------+-------------------------------------+
# | app_id|label|review_id|                          review_text|
# +-------+-----+---------+-------------------------------------+
# |1468810|  1.0| 85853406|还可以，比修仙模拟器吸引人，但是画...|
# |1468810|  1.0| 85849804|希望以後能帶著老婆道侶女徒弟一起刷...|
# +-------+-----+---------+-------------------------------------+
#
# +-----+-------------------------------------+----------+--------------------+-----------+
# |label|                          review_text|prediction|         probability|label_index|
# +-----+-------------------------------------+----------+--------------------+-----------+
# |  1.0|还可以，比修仙模拟器吸引人，但是画...|       0.0|[0.86618000513816...|        0.0|
# |  1.0|希望以後能帶著老婆道侶女徒弟一起刷...|       0.0|[0.86618000513816...|        0.0|
# +-----+-------------------------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[138.   3.]
#  [ 25.  14.]]
# ========= 2023-05-26 15:01:40 =========
# +-------+-----+---------+-------------------------------------+
# | app_id|label|review_id|                          review_text|
# +-------+-----+---------+-------------------------------------+
# |1468810|  1.0| 85849527|前几个小时玩得很爽，后面太重复了。...|
# |1468810|  1.0| 85842965|                     Really addictive|
# |1468810|  1.0| 85833267|                                10/10|
# |1468810|  1.0| 85823817|                    It's perfect game|
# |1468810|  1.0| 85822122|很棒，我就提两个建议，宠物系统赶紧...|
# +-------+-----+---------+-------------------------------------+
#
# +-----+-------------------------------------+----------+--------------------+-----------+
# |label|                          review_text|prediction|         probability|label_index|
# +-----+-------------------------------------+----------+--------------------+-----------+
# |  1.0|前几个小时玩得很爽，后面太重复了。...|       0.0|[0.86618000513816...|        0.0|
# |  1.0|                     Really addictive|       0.0|[0.96770307462822...|        0.0|
# |  1.0|                                10/10|       0.0|[0.95457866638434...|        0.0|
# |  1.0|                    It's perfect game|       0.0|[0.92108489695035...|        0.0|
# |  1.0|很棒，我就提两个建议，宠物系统赶紧...|       0.0|[0.86618000513816...|        0.0|
# +-----+-------------------------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[143.   3.]
#  [ 25.  14.]]
# ========= 2023-05-26 15:01:50 =========
# +-------+-----+---------+--------------------------------+
# | app_id|label|review_id|                     review_text|
# +-------+-----+---------+--------------------------------+
# |1468810|  1.0| 85821762|            go to learn chine...|
# |1468810|  1.0| 85819609|               i like this game.|
# |1468810|  0.0| 85818957|10级的你想升到11级，需要6个一...|
# +-------+-----+---------+--------------------------------+
#
# +-----+--------------------------------+----------+--------------------+-----------+
# |label|                     review_text|prediction|         probability|label_index|
# +-----+--------------------------------+----------+--------------------+-----------+
# |  1.0|            go to learn chine...|       0.0|[0.75121626653625...|        0.0|
# |  1.0|               i like this game.|       0.0|[0.88673601443826...|        0.0|
# |  0.0|10级的你想升到11级，需要6个一...|       0.0|[0.86604071919167...|        1.0|
# +-----+--------------------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[145.   3.]
#  [ 26.  14.]]

# %%
ssc_t.stop()
# Out:
# ----- Stopping... this may take a few seconds -----
