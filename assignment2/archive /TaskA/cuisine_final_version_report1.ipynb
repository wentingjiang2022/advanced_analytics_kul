# %%
#pip install reportlab
import json
import glob
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import itertools
from matplotlib.backends.backend_pdf import PdfPages
from sklearn.metrics import accuracy_score
import seaborn as sns
from sklearn.metrics import confusion_matrix
import pandas as pd
import random
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model

# %%
loc='/Users/wentingjiang/Downloads/assignment2/'

# %%
with open(loc+'dataset.json', 'r') as file:
    data = json.load(file)

print(data)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# look at json
# multiple labels per restaurant
for i in range(20):
    print(i)
    labels = [d['label'] for d in data[i]['cuisines']]
    print(labels)
# Out:
# 0
# ['Greek']
# 1
# ['Modern French']
# 2
# ['Seafood']
# 3
# ['Modern French']
# 4
# ['Seafood', 'Classic Cuisine']
# 5
# ['Seafood']
# 6
# ['Organic', 'Market Cuisine']
# 7
# ['Japanese']
# 8
# ['Belgian', 'Classic Cuisine']
# 9
# ['Classic Cuisine', 'Belgian']
# 10
# ['Classic French']
# 11
# ['Belgian', 'Classic Cuisine']
# 12
# ['Classic Cuisine']
# 13
# ['Modern French', 'Creative']
# 14
# ['Traditional Cuisine', 'Belgian']
# 15
# ['Creative']
# 16
# ['Italian']
# 17
# ['Belgian']
# 18
# ['Seasonal Cuisine', 'Belgian']
# 19
# ['Seasonal Cuisine']

# %%
# extract image IDs of one restaurant
one_restaurant_info=data[0]['more_details']['full_images']
one_restaurant_images=[i['image_id'] for i in one_restaurant_info]
one_restaurant_images
# Out:
# ['2088757', '2182000', '4151606', '4151588', '2224983']

# %%
# do this for all restaurants
import random
res_image_dic={}
cuisine_dic={}
for res in data:
    # use cuisine type as restaurant 
    res_id= res['identifier']
    one_restaurant_info=res['more_details']['full_images']
    one_restaurant_images=[i['image_id'] for i in one_restaurant_info]
    if len(one_restaurant_images)!=0:
    # select 1 images per restaurant, otherwise too many images
        selected= one_restaurant_images[-1]#random.choices(one_restaurant_images,k=1)
    res_image_dic[res_id]=selected
    cuisine_dic[res_id] = [d['label'] for d in res['cuisines']]

# %%
len(cuisine_dic)
# Out:
# 16455

# %%
# get all cuisine names
flat_list = [item for sublist in cuisine_dic.values() for item in sublist]
flat_list
# Out:
# ['Greek',
#  'Modern French',
#  'Seafood',
#  'Modern French',
#  'Seafood',
#  'Classic Cuisine',
#  'Seafood',
#  'Organic',
#  'Market Cuisine',
#  'Japanese',
#  'Belgian',
#  'Classic Cuisine',
#  'Classic Cuisine',
#  'Belgian',
#  'Classic French',
#  'Belgian',
#  'Classic Cuisine',
#  'Classic Cuisine',
#  'Modern French',
#  'Creative',
#  'Traditional Cuisine',
#  'Belgian',
#  'Creative',
#  'Italian',
#  'Belgian',
#  'Seasonal Cuisine',
#  'Belgian',
#  'Seasonal Cuisine',
#  'Spanish',
#  'Seafood',
#  'Italian',
#  'Sicilian',
#  'Belgian',
#  'Traditional Cuisine',
#  'Classic Cuisine',
#  'Country cooking',
#  'Asian Influences',
#  'Creative',
#  'Modern Cuisine',
#  'International',
#  'Traditional Cuisine',
#  'Classic French',
#  'Italian',
#  'Vietnamese Contemporary',
#  'Meats and Grills',
#  'Modern French',
#  'Regional Cuisine',
#  'Classic Cuisine',
#  'Market Cuisine',
#  'Traditional Cuisine',
#  'Cuisine from South West France',
#  'Country cooking',
#  'French',
#  'Italian',
#  'Organic',
#  'Vegetarian',
#  'Vegetarian',
#  'Organic',
#  'Modern Cuisine',
#  'Creative',
#  'Home Cooking',
#  'Meats and Grills',
#  'Classic Cuisine',
#  'Creative',
#  'Modern Cuisine',
#  'Organic',
#  'Vegetarian',
#  'Organic',
#  'Italian',
#  'Italian',
#  'Sharing',
#  'Country cooking',
#  'Italian',
#  'Contemporary',
#  'Market Cuisine',
#  'Belgian',
#  'Classic Cuisine',
#  'Creative',
#  'Organic',
#  'Modern French',
#  'World Cuisine',
#  'Modern French',
#  'Creative French',
#  'Classic Cuisine',
#  'Italian',
#  'Modern Cuisine',
#  'Organic',
#  'French',
#  'Classic Cuisine',
#  'French Contemporary',
#  'Italian',
#  'Italian',
#  'Sicilian',
#  'Greek',
#  'Modern Cuisine',
#  'Asian',
#  'French',
#  'Classic Cuisine',
#  'Korean',
#  'Asian',
#  'Seafood',
#  'Modern Cuisine',
#  'Japanese',
#  'Sushi',
#  'Chinese',
#  'Sichuan',
#  'Traditional Cuisine',
#  'Market Cuisine',
#  'Mediterranean Cuisine',
#  'Seafood',
#  'Classic Cuisine',
#  'Italian',
#  'Creative French',
#  'Creative',
#  'Organic',
#  'Belgian',
#  'Classic Cuisine',
#  'Roman',
#  'Meats and Grills',
#  'Italian',
#  'Japanese',
#  'Sushi',
#  'Grills',
#  'Meats and Grills',
#  'Classic French',
#  'Italian',
#  'Italian',
#  'Classic Cuisine',
#  'Thai',
#  'Asian',
#  'Italian',
#  'Organic',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Lebanese',
#  'Middle Eastern',
#  'Modern Cuisine',
#  'Asian Influences',
#  'Modern French',
#  'Modern French',
#  'Italian',
#  'Vietnamese',
#  'Asian',
#  'Classic Cuisine',
#  'Italian',
#  'Thai',
#  'Creative',
#  'Mediterranean Cuisine',
#  'Classic Cuisine',
#  'Country cooking',
#  'Classic French',
#  'Lebanese',
#  'Middle Eastern',
#  'Classic Cuisine',
#  'Chinese',
#  'Meats and Grills',
#  'Classic Cuisine',
#  'Belgian',
#  'Modern Cuisine',
#  'Creative',
#  'Creative French',
#  'Classic Cuisine',
#  'Traditional Cuisine',
#  'Classic French',
#  'Classic Cuisine',
#  'Home Cooking',
#  'Creative French',
#  'Modern French',
#  'Mediterranean Cuisine',
#  'Classic Cuisine',
#  'Classic Cuisine',
#  'Chinese',
#  'Fusion',
#  'Modern French',
#  'Market Cuisine',
#  'Creative',
#  'Creative French',
#  'Spanish',
#  'Sharing',
#  'Italian',
#  'Italian',
#  'Creative',
#  'Modern French',
#  'Belgian',
#  'Classic Cuisine',
#  'Market Cuisine',
#  'Modern Cuisine',
#  'Traditional Cuisine',
#  'Sharing',
#  'Modern Cuisine',
#  'Lyonnaise',
#  'Classic Cuisine',
#  'Seafood',
#  'Classic Cuisine',
#  'Creative French',
#  'Classic Cuisine',
#  'Regional Cuisine',
#  'Italian',
#  'Modern Cuisine',
#  'Italian',
#  'Traditional Cuisine',
#  'Traditional Cuisine',
#  'Seafood',
#  'Creative',
#  'Market Cuisine',
#  'Modern Cuisine',
#  'Thai',
#  'Modern French',
#  'French Contemporary',
#  'Creative French',
#  'French',
#  'Traditional Cuisine',
#  'Modern Cuisine',
#  'Traditional Cuisine',
#  'French',
#  'Traditional Cuisine',
#  'Country cooking',
#  'Market Cuisine',
#  'Market Cuisine',
#  'Classic French',
#  'Organic',
#  'Creative French',
#  'Fusion',
#  'Modern Cuisine',
#  'Modern French',
#  'Organic',
#  'Vegetarian',
#  'Chicken Specialities',
#  'Sharing',
#  'Contemporary',
#  'Creative French',
#  'Creative',
#  'Creative',
#  'Modern Cuisine',
#  'French Contemporary',
#  'Classic Cuisine',
#  'Modern French',
#  'Traditional Cuisine',
#  'Seafood',
#  'Classic Cuisine',
#  'Modern Cuisine',
#  'Seasonal Cuisine',
#  'Belgian',
#  'Italian',
#  'Home Cooking',
#  'Creative',
#  'Modern Cuisine',
#  'Belgian',
#  'Market Cuisine',
#  'Modern French',
#  'Creative French',
#  'Classic Cuisine',
#  'Meats and Grills',
#  'Classic Cuisine',
#  'Modern Cuisine',
#  'Creative',
#  'Modern Cuisine',
#  'Italian',
#  'Modern French',
#  'Market Cuisine',
#  'Modern Cuisine',
#  'Market Cuisine',
#  'Belgian',
#  'Modern Cuisine',
#  'Contemporary',
#  'Market Cuisine',
#  'Modern French',
#  'Modern French',
#  'Modern French',
#  'Modern Cuisine',
#  'French',
#  'Seasonal Cuisine',
#  'Market Cuisine',
#  'Market Cuisine',
#  'Italian',
#  'Traditional Cuisine',
#  'Modern Cuisine',
#  'Seasonal Cuisine',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Creative',
#  'Creative',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Traditional Cuisine',
#  'Modern French',
#  'French Contemporary',
#  'Modern French',
#  'Modern French',
#  'Greek',
#  'Creative French',
#  'Belgian',
#  'French',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Market Cuisine',
#  'Seasonal Cuisine',
#  'Italian',
#  'Meats and Grills',
#  'Modern Cuisine',
#  'Grills',
#  'Barbecue',
#  'Modern Cuisine',
#  'Modern French',
#  'Modern Cuisine',
#  'French',
#  'Modern French',
#  'Meats and Grills',
#  'Market Cuisine',
#  'Creative',
#  'Modern Cuisine',
#  'Market Cuisine',
#  'Traditional Cuisine',
#  'Market Cuisine',
#  'Modern Cuisine',
#  'Creative',
#  'Market Cuisine',
#  'Modern French',
#  'Creative French',
#  'Modern Cuisine',
#  'Seasonal Cuisine',
#  'Creative',
#  'Creative',
#  'Creative French',
#  'Modern Cuisine',
#  'Market Cuisine',
#  'Classic Cuisine',
#  'Organic',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Market Cuisine',
#  'Classic Cuisine',
#  'Classic Cuisine',
#  'Traditional Cuisine',
#  'Meats and Grills',
#  'Creative French',
#  'Modern Cuisine',
#  'Barbecue',
#  'Market Cuisine',
#  'Seasonal Cuisine',
#  'French Contemporary',
#  'Creative',
#  'Classic Cuisine',
#  'Contemporary',
#  'Creative French',
#  'Modern French',
#  'Creative',
#  'Market Cuisine',
#  'Modern Cuisine',
#  'Modern French',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Classic French',
#  'Italian',
#  'Seafood',
#  'Chinese',
#  'Modern Cuisine',
#  'Sharing',
#  'Belgian',
#  'French Contemporary',
#  'Classic French',
#  'Seafood',
#  'Grills',
#  'Vietnamese',
#  'Chinese',
#  'Creative',
#  'Belgian',
#  'Latin American',
#  'Modern French',
#  'Classic Cuisine',
#  'Modern Cuisine',
#  'Seasonal Cuisine',
#  'Modern Cuisine',
#  'Japanese',
#  'Sushi',
#  'Modern French',
#  'Creative French',
#  'Traditional Cuisine',
#  'Creative',
#  'Creative',
#  'Classic French',
#  'Seasonal Cuisine',
#  'Creative',
#  'Italian Contemporary',
#  'Creative French',
#  'Fusion',
#  'Asian Contemporary',
#  'Creative French',
#  'Organic',
#  'Market Cuisine',
#  'French',
#  'Belgian',
#  'Seafood',
#  'Asian',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Classic Cuisine',
#  'French Contemporary',
#  'Creative',
#  'Chinese',
#  'Sichuan',
#  'Vegan',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Modern French',
#  'Market Cuisine',
#  'Modern French',
#  'Italian',
#  'Modern Cuisine',
#  'Classic Cuisine',
#  'Modern Cuisine',
#  'Grills',
#  'Classic Cuisine',
#  'Meats and Grills',
#  'Traditional Cuisine',
#  'Creative',
#  'Seafood',
#  'Vegetarian',
#  'Creative French',
#  'Modern Cuisine',
#  'Market Cuisine',
#  'Seafood',
#  'Classic Cuisine',
#  'Market Cuisine',
#  'French',
#  'Italian',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Spanish',
#  'Organic',
#  'International',
#  'Seasonal Cuisine',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Chinese',
#  'Organic',
#  'Modern French',
#  'Market Cuisine',
#  'Market Cuisine',
#  'Seasonal Cuisine',
#  'Modern Cuisine',
#  'Creative',
#  'Modern Cuisine',
#  'Classic Cuisine',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Modern French',
#  'French Contemporary',
#  'Modern French',
#  'Modern Cuisine',
#  'Classic Cuisine',
#  'Market Cuisine',
#  'Traditional Cuisine',
#  'Market Cuisine',
#  'Creative French',
#  'Belgian',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Creative',
#  'Modern Cuisine',
#  'Spanish Contemporary',
#  'Seasonal Cuisine',
#  'Market Cuisine',
#  'Market Cuisine',
#  'Creative',
#  'Organic',
#  'Traditional Cuisine',
#  'French',
#  'Classic Cuisine',
#  'Creative',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Modern French',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Japanese',
#  'Modern French',
#  'Traditional Cuisine',
#  'Thai',
#  'Vegetarian',
#  'Seafood',
#  'Contemporary',
#  'Modern French',
#  'Market Cuisine',
#  'Modern Cuisine',
#  'International',
#  'Classic Cuisine',
#  'Creative',
#  'Modern Cuisine',
#  'Modern French',
#  'Modern Cuisine',
#  'Asian',
#  'Modern Cuisine',
#  'Market Cuisine',
#  'World Cuisine',
#  'Creative French',
#  'Modern Cuisine',
#  'Asian Influences',
#  'Creative French',
#  'Flemish',
#  'Modern French',
#  'Organic',
#  'Seasonal Cuisine',
#  'Classic Cuisine',
#  'Modern French',
#  'Modern French',
#  'Seasonal Cuisine',
#  'Classic French',
#  'Creative French',
#  'Traditional Cuisine',
#  'Seasonal Cuisine',
#  'Meats and Grills',
#  'Modern French',
#  'Spanish',
#  'Market Cuisine',
#  'Seasonal Cuisine',
#  'Belgian',
#  'Classic Cuisine',
#  'Italian',
#  'Modern French',
#  'Market Cuisine',
#  'Creative',
#  'Modern Cuisine',
#  'French Contemporary',
#  'Modern French',
#  'Traditional Cuisine',
#  'Creative French',
#  'Modern Cuisine',
#  'Classic Cuisine',
#  'Modern Cuisine',
#  'Classic French',
#  'Traditional Cuisine',
#  'Traditional Cuisine',
#  'Modern Cuisine',
#  'Modern French',
#  'French',
#  'Modern French',
#  'Modern Cuisine',
#  'Contemporary',
#  'Creative',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Seafood',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Traditional Cuisine',
#  'Traditional Cuisine',
#  'Seafood',
#  'Modern French',
#  'Modern Cuisine',
#  'Classic Cuisine',
#  'Traditional Cuisine',
#  'Classic French',
#  'French Contemporary',
#  'Seasonal Cuisine',
#  'Creative French',
#  'Modern French',
#  'Modern Cuisine',
#  'Modern French',
#  'Market Cuisine',
#  'Classic Cuisine',
#  'French',
#  'Meats and Grills',
#  'Modern Cuisine',
#  'Turkish',
#  'Modern Cuisine',
#  'Italian',
#  'Modern Cuisine',
#  'Creative',
#  'Modern Cuisine',
#  'Italian',
#  'Modern Cuisine',
#  'Market Cuisine',
#  'French',
#  'Modern Cuisine',
#  'Market Cuisine',
#  'Modern Cuisine',
#  'Chinese',
#  'Contemporary',
#  'Traditional Cuisine',
#  'Modern French',
#  'Market Cuisine',
#  'Belgian',
#  'Organic',
#  'Modern French',
#  'World Cuisine',
#  'Creative French',
#  'Market Cuisine',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Italian',
#  'Modern Cuisine',
#  'Traditional Cuisine',
#  'Traditional Cuisine',
#  'Classic French',
#  'Modern Cuisine',
#  'Seafood',
#  'Modern French',
#  'French',
#  'Seasonal Cuisine',
#  'Traditional Cuisine',
#  'Seasonal Cuisine',
#  'French',
#  'Grills',
#  'Traditional Cuisine',
#  'Classic Cuisine',
#  'Traditional Cuisine',
#  'Market Cuisine',
#  'Creative',
#  'Creative French',
#  'Creative French',
#  'Modern Cuisine',
#  'Market Cuisine',
#  'Modern French',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Meats and Grills',
#  'Classic Cuisine',
#  'Market Cuisine',
#  'Modern Cuisine',
#  'Modern French',
#  'Seafood',
#  'Modern French',
#  'Modern French',
#  'Creative French',
#  'Italian',
#  'Modern French',
#  'Creative',
#  'Modern Cuisine',
#  'French Contemporary',
#  'Modern French',
#  'Creative',
#  'Modern Cuisine',
#  'Seasonal Cuisine',
#  'Traditional Cuisine',
#  'Market Cuisine',
#  'Modern Cuisine',
#  'Creative',
#  'Modern French',
#  'Market Cuisine',
#  'Modern Cuisine',
#  'Modern French',
#  'Modern French',
#  'Country cooking',
#  'Modern French',
#  'Creative French',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Contemporary',
#  'Creative French',
#  'Creative',
#  'Modern French',
#  'Modern Cuisine',
#  'Creative',
#  'Italian',
#  'Modern French',
#  'Modern Cuisine',
#  'Creative French',
#  'Modern French',
#  'Classic French',
#  'French Contemporary',
#  'Modern French',
#  'Home Cooking',
#  'Modern Cuisine',
#  'French',
#  'Classic Cuisine',
#  'Modern French',
#  'Creative',
#  'Classic Cuisine',
#  'Market Cuisine',
#  'Market Cuisine',
#  'Market Cuisine',
#  'Classic Cuisine',
#  'Organic',
#  'Creative',
#  'Seafood',
#  'Seafood',
#  'Country cooking',
#  'Modern Cuisine',
#  'Seafood',
#  'Modern Cuisine',
#  'Creative',
#  'Modern Cuisine',
#  'Modern French',
#  'Market Cuisine',
#  'Creative French',
#  'Market Cuisine',
#  'Modern French',
#  'Traditional Cuisine',
#  'Creative French',
#  'Country cooking',
#  'Seasonal Cuisine',
#  'Market Cuisine',
#  'Modern Cuisine',
#  'Creative',
#  'Classic French',
#  'Modern Cuisine',
#  'Market Cuisine',
#  'Classic Cuisine',
#  'Modern French',
#  'Country cooking',
#  'Modern Cuisine',
#  'Traditional Cuisine',
#  'Modern French',
#  'Classic French',
#  'Creative',
#  'Creative',
#  'Modern Cuisine',
#  'Market Cuisine',
#  'Country cooking',
#  'Classic Cuisine',
#  'Modern Cuisine',
#  'Modern French',
#  'Creative',
#  'Seasonal Cuisine',
#  'Modern French',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Creative',
#  'Modern Cuisine',
#  'Asian',
#  'Asian Influences',
#  'Italian',
#  'Modern Cuisine',
#  'Modern French',
#  'Modern Cuisine',
#  'Classic Cuisine',
#  'Modern French',
#  'Modern Cuisine',
#  'Creative',
#  'Grills',
#  'Meats and Grills',
#  'Modern Cuisine',
#  'Creative',
#  'Modern Cuisine',
#  'Market Cuisine',
#  'Modern Cuisine',
#  'French Contemporary',
#  'Seasonal Cuisine',
#  'Seasonal Cuisine',
#  'Market Cuisine',
#  'Country cooking',
#  'Creative',
#  'Country cooking',
#  'Market Cuisine',
#  'Market Cuisine',
#  'Mediterranean Cuisine',
#  'Spanish',
#  'Italian',
#  'Modern Cuisine',
#  'Market Cuisine',
#  'Modern French',
#  'Modern Cuisine',
#  'Italian',
#  'Modern French',
#  'Modern Cuisine',
#  'Creative',
#  'Modern French',
#  'Market Cuisine',
#  'Modern Cuisine',
#  'Meats and Grills',
#  'Modern Cuisine',
#  'Modern French',
#  'Modern Cuisine',
#  'Creative French',
#  'Creative',
#  'Market Cuisine',
#  'Creative French',
#  'Creative',
#  'Creative French',
#  'Modern Cuisine',
#  'Mediterranean Cuisine',
#  'Creative French',
#  'Classic Cuisine',
#  'Creative',
#  'Modern Cuisine',
#  'Creative',
#  'Market Cuisine',
#  'Portuguese',
#  'Italian Contemporary',
#  'Traditional Cuisine',
#  'Market Cuisine',
#  'Seasonal Cuisine',
#  'Modern Cuisine',
#  'Modern French',
#  'Traditional Cuisine',
#  'French Contemporary',
#  'Modern French',
#  'Modern Cuisine',
#  'Creative',
#  'World Cuisine',
#  'Creative French',
#  'Modern Cuisine',
#  'Modern French',
#  'Creative French',
#  'Creative',
#  'Modern French',
#  'Mediterranean Cuisine',
#  'Market Cuisine',
#  'International',
#  'Market Cuisine',
#  'Creative French',
#  'Flemish',
#  'Regional Cuisine',
#  'Japanese',
#  'Modern Cuisine',
#  'World Cuisine',
#  'World Cuisine',
#  'French Contemporary',
#  'Modern French',
#  'Traditional Cuisine',
#  'French',
#  'Market Cuisine',
#  'Modern French',
#  'Creative',
#  'French',
#  'Asian Influences',
#  'Modern Cuisine',
#  'Creative',
#  'Classic French',
#  'Creative',
#  'World Cuisine',
#  'Country cooking',
#  'Market Cuisine',
#  'Market Cuisine',
#  'Creative French',
#  'Modern French',
#  'Asian Influences',
#  'Creative',
#  'Creative',
#  'Modern Cuisine',
#  'Seafood',
#  'Modern Cuisine',
#  'Italian',
#  'Seafood',
#  'Classic Cuisine',
#  'Modern Cuisine',
#  'Regional Cuisine',
#  'Market Cuisine',
#  'Regional Cuisine',
#  'Modern Cuisine',
#  'Creative',
#  'Country cooking',
#  'Traditional Cuisine',
#  'Mediterranean Cuisine',
#  'French',
#  'Belgian',
#  'Modern Cuisine',
#  'Market Cuisine',
#  'Creative',
#  'Country cooking',
#  'Market Cuisine',
#  'Creative',
#  'Classic Cuisine',
#  'Belgian',
#  'Italian',
#  'Modern French',
#  'Modern Cuisine',
#  'Market Cuisine',
#  'Scandinavian',
#  'Country cooking',
#  'Creative French',
#  'Modern French',
#  'Modern Cuisine',
#  'Italian',
#  'Organic',
#  'Modern French',
#  'Traditional Cuisine',
#  'Modern French',
#  'Cuisine from the Marches',
#  'Regional Cuisine',
#  'Market Cuisine',
#  'Grills',
#  'Thai',
#  'Traditional Cuisine',
#  'Creative',
#  'Mexican',
#  'Traditional Cuisine',
#  'Italian',
#  'Classic Cuisine',
#  'Belgian',
#  'Creative French',
#  'Fusion',
#  'Traditional Cuisine',
#  'Italian',
#  'Modern Cuisine',
#  'Classic Cuisine',
#  'French Contemporary',
#  'French Contemporary',
#  'Classic Cuisine',
#  'Modern Cuisine',
#  'Creative',
#  'Creative',
#  'French Contemporary',
#  'Classic French',
#  'Italian Contemporary',
#  'Contemporary',
#  'Creative French',
#  'Modern Cuisine',
#  'Grills',
#  'Traditional Cuisine',
#  'Modern Cuisine',
#  'Italian',
#  'Modern Cuisine',
#  'Thai',
#  'Asian',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Contemporary',
#  'French',
#  'Modern French',
#  'Mediterranean Cuisine',
#  'Creative',
#  'Italian',
#  'Modern Cuisine',
#  'Creative',
#  'Modern Cuisine',
#  'Modern French',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Modern French',
#  'Modern French',
#  'Modern Cuisine',
#  'French',
#  'Modern French',
#  'Modern French',
#  'Mediterranean Cuisine',
#  'Market Cuisine',
#  'Mediterranean Cuisine',
#  'Modern French',
#  'Modern Cuisine',
#  'Seafood',
#  'Modern French',
#  'Creative',
#  'Modern French',
#  'Modern French',
#  'Creative French',
#  'Creative',
#  'Italian',
#  'Market Cuisine',
#  'Modern Cuisine',
#  'Seafood',
#  'Thai',
#  'Italian',
#  'Seasonal Cuisine',
#  'Country cooking',
#  'Creative',
#  'Asian Influences',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Market Cuisine',
#  'Modern Cuisine',
#  'Asian',
#  'Asian Contemporary',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Market Cuisine',
#  'Modern Cuisine',
#  'Traditional Cuisine',
#  'Country cooking',
#  'Modern Cuisine',
#  'Modern French',
#  'Belgian',
#  'Classic French',
#  'French Contemporary',
#  'World Cuisine',
#  'Meats and Grills',
#  'Grills',
#  'Modern French',
#  'International',
#  'Modern Cuisine',
#  'Contemporary',
#  'Mediterranean Cuisine',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Traditional Cuisine',
#  'Modern French',
#  'Seasonal Cuisine',
#  'Modern Cuisine',
#  'Modern Cuisine',
#  'Market Cuisine',
#  'Classic Cuisine',
#  'Creative',
#  'Modern Cuisine',
#  'Modern French',
#  'Italian',
#  'Modern French',
#  'Modern Cuisine',
#  'Creative French',
#  'Modern Cuisine',
#  'Seafood',
#  'Modern Cuisine',
#  'French Contemporary',
#  'Creative French',
#  'Modern Cuisine',
#  'Country cooking',
#  'French Contemporary',
#  ...]

# %%
from collections import Counter

counter = Counter(flat_list)

df = pd.DataFrame(list(counter.items()), columns=['Element', 'Count'])

# Sort the DataFrame by count in descending order
df = df.sort_values(by=['Count'], ascending=False)

# Reset the index
df = df.reset_index(drop=True)

# look at the most frequently appearing types
dfs= df.iloc[:30,:]

# %%
len(df.Element.unique())
# Out:
# 275

# %%
#df = df.sort_values(by='Number of Restaurants', ascending=False)
plt.barh(dfs['Element'], dfs['Count'])
plt.xlabel('Number of Restaurants')
plt.ylabel('Cuisine')
plt.title('Number of Restaurants by Cuisine')
plt.show()

# %%
country_tags= [ #'Modern Cuisine',
#  'Traditional Cuisine',
#  'Creative',
#  'Contemporary',
#  'Market Cuisine',
#  'Seafood',
 'Italian',
#  'Classic Cuisine',
 'Japanese',
#  'Country cooking',
#  'Mediterranean Cuisine',
#  'International',
#  'Regional Cuisine',
 'French',
  'Modern British',
#  'Street Food',
#  'Modern French',
#  'Seasonal Cuisine',
  'Cantonese',
#  'American',
  'Sushi',
#  'Classic French',
 'Chinese',
 'Thai',
#  'Fusion',
#  'Italian Contemporary',
#  'French Contemporary',
 'Indian',
#  'Meats and Grills',
# 'Mexican'
]

# %%
# filter restaurant ID that corresponds to the tag above 
# Filter the keys in the dictionary whose items are in the list
filtered_dict = {k: v for k, v in cuisine_dic.items() if any(elem in v for elem in country_tags)}

# Convert the filtered dictionary to a DataFrame
filtered_restaurant=pd.DataFrame.from_dict(filtered_dict, orient='index')#, columns=['Cuisine'])
filtered_restaurant.columns=['tag1','tag2']
filtered_restaurant['tag1'] = filtered_restaurant['tag1'].replace('Cantonese', 'Chinese')

filtered_restaurant['tag1'] = filtered_restaurant['tag1'].replace('Sushi', 'Japanese')
filtered_restaurant['tag1'] = filtered_restaurant['tag1'].replace('Modern French', 'French')

# in someg cases, a restaurant has two tags, two similar country cuisines

# %%
filtered_restaurant_single_tag=filtered_restaurant[filtered_restaurant['tag2'].isna()].reset_index()
filtered_restaurant_single_tag.head()
# Out:
#      index      tag1  tag2
# 0   113876  Japanese  None
# 1   504797   Italian  None
# 2  1201928   Italian  None
# 3   566485    French  None
# 4   457944   Italian  None

# %%
# classes are somewhat imbalanced
filtered_restaurant_single_tag.groupby('tag1').count()

#could just choose the classes that are more balanced: French, Italian, Japense, Modern British
# Out:
#                 index  tag2
# tag1
# Chinese           311     0
# French            311     0
# Indian            111     0
# Italian           436     0
# Japanese          551     0
# Modern British    339     0
# Thai              166     0

# %%
restaurant_id_selected =list(filtered_restaurant_single_tag['index'])

# %%
image_names = [res_image_dic[k] for k in restaurant_id_selected]
#image_names

filtered_restaurant_single_tag['image_id']=image_names
#filtered_restaurant_single_tag

image_id_label=filtered_restaurant_single_tag.set_index('image_id')['tag1'].to_dict()
image_id_label
# Out:
# {'1955140': 'Japanese',
#  '1956974': 'Italian',
#  '4609070': 'Italian',
#  '1911250': 'French',
#  '4152648': 'Italian',
#  '4668524': 'Italian',
#  '2146157': 'Italian',
#  '5611627': 'Italian',
#  '2221633': 'Italian',
#  '5489548': 'French',
#  '2254872': 'Italian',
#  '2298149': 'Italian',
#  '4961770': 'Italian',
#  '2051604': 'Italian',
#  '2251131': 'Italian',
#  '2191687': 'Italian',
#  '4493783': 'Italian',
#  '1908528': 'Italian',
#  '2040600': 'Thai',
#  '2260291': 'Chinese',
#  '1958831': 'Italian',
#  '2090936': 'Italian',
#  '1955743': 'Italian',
#  '5030848': 'Italian',
#  '5471558': 'Thai',
#  '1955875': 'Italian',
#  '5320439': 'Italian',
#  '4829194': 'Italian',
#  '2694413': 'Italian',
#  '2218429': 'Italian',
#  '4971864': 'Chinese',
#  '2156007': 'Chinese',
#  '2280804': 'Japanese',
#  '2142853': 'Thai',
#  '4575262': 'Italian',
#  '2247280': 'French',
#  '2141684': 'Chinese',
#  '2181089': 'Italian',
#  '2117355': 'Italian',
#  '4210301': 'Italian',
#  '2281150': 'Italian',
#  '1955330': 'Japanese',
#  '5439551': 'French',
#  '4670402': 'Italian',
#  '2646999': 'Italian',
#  '1957722': 'Italian',
#  '1914535': 'Italian',
#  '2191156': 'Italian',
#  '4292385': 'Italian',
#  '2643058': 'Thai',
#  '2205572': 'Italian',
#  '2298071': 'Italian',
#  '2646110': 'Italian',
#  '4184319': 'Italian',
#  '5609624': 'French',
#  '2640444': 'Japanese',
#  '2176959': 'French',
#  '1919452': 'French',
#  '5598782': 'Italian',
#  '2241383': 'Italian',
#  '5304231': 'Japanese',
#  '2220893': 'French',
#  '1940598': 'Chinese',
#  '2219491': 'Italian',
#  '674870': 'Italian',
#  '5490632': 'Italian',
#  '5463983': 'Japanese',
#  '5609665': 'Chinese',
#  '447916': 'Italian',
#  '5284228': 'Italian',
#  '4982066': 'Italian',
#  '5604149': 'Thai',
#  '4478627': 'Italian',
#  '5595760': 'Italian',
#  '365356': 'Japanese',
#  '811848': 'Japanese',
#  '359499': 'Japanese',
#  '752905': 'Chinese',
#  '359988': 'Japanese',
#  '691844': 'Japanese',
#  '5636414': 'Chinese',
#  '458804': 'Italian',
#  '690153': 'Italian',
#  '5471263': 'Japanese',
#  '769076': 'Chinese',
#  '804984': 'Italian',
#  '366188': 'Japanese',
#  '748593': 'Italian',
#  '705061': 'Japanese',
#  '360845': 'Italian',
#  '711769': 'Italian',
#  '5439143': 'Japanese',
#  '811001': 'Japanese',
#  '4104458': 'Italian',
#  '358709': 'Japanese',
#  '5435152': 'Italian',
#  '807960': 'Italian',
#  '474576': 'Italian',
#  '5639362': 'Japanese',
#  '758449': 'Japanese',
#  '719093': 'Thai',
#  '649020': 'Italian',
#  '361496': 'Italian',
#  '443766': 'Japanese',
#  '361353': 'Italian',
#  '659013': 'Italian',
#  '778212': 'Italian',
#  '4630036': 'Italian',
#  '357714': 'Italian',
#  '2133454': 'Japanese',
#  '817410': 'Japanese',
#  '370316': 'Japanese',
#  '5465252': 'Italian',
#  '435019': 'Italian',
#  '463892': 'Japanese',
#  '4098172': 'Italian',
#  '4158607': 'Italian',
#  '374671': 'Italian',
#  '3124052': 'Japanese',
#  '755832': 'Japanese',
#  '485681': 'Italian',
#  '459259': 'Italian',
#  '714290': 'Japanese',
#  '736161': 'Italian',
#  '360276': 'Japanese',
#  '297614': 'Italian',
#  '4159686': 'Thai',
#  '761185': 'Japanese',
#  '378935': 'Italian',
#  '520143': 'Italian',
#  '459703': 'Italian',
#  '4335470': 'Italian',
#  '775098': 'Italian',
#  '689916': 'Chinese',
#  '648222': 'Italian',
#  '782735': 'Italian',
#  '5428244': 'Japanese',
#  '5568801': 'Italian',
#  '5575591': 'Japanese',
#  '5575214': 'French',
#  '5580263': 'French',
#  '5575367': 'Chinese',
#  '5575323': 'Japanese',
#  '5580248': 'French',
#  '3833645': 'Japanese',
#  '5411111': 'French',
#  '5449806': 'Japanese',
#  '5455586': 'Japanese',
#  '5423683': 'Modern British',
#  '5591280': 'Modern British',
#  '5464251': 'Modern British',
#  '5315246': 'Modern British',
#  '5414007': 'Indian',
#  '5535783': 'Modern British',
#  '5440724': 'Modern British',
#  '5375022': 'Modern British',
#  '5480497': 'Modern British',
#  '5531463': 'Italian',
#  '5570366': 'Modern British',
#  '5565865': 'Italian',
#  '5530455': 'Thai',
#  '5516228': 'French',
#  '5457618': 'Italian',
#  '5409578': 'Japanese',
#  '5514865': 'Italian',
#  '5333155': 'Modern British',
#  '5158310': 'Modern British',
#  '5332231': 'Modern British',
#  '4983711': 'Japanese',
#  '5497019': 'Modern British',
#  '5134309': 'Modern British',
#  '5518962': 'Modern British',
#  '5142831': 'Italian',
#  '5136774': 'Modern British',
#  '5161836': 'Italian',
#  '5382068': 'Modern British',
#  '2024117': 'Japanese',
#  '1986521': 'Japanese',
#  '1986297': 'Japanese',
#  '2290525': 'Japanese',
#  '2206050': 'Italian',
#  '5436922': 'Chinese',
#  '5299035': 'Chinese',
#  '4790495': 'Italian',
#  '2061230': 'Chinese',
#  '2139592': 'Chinese',
#  '2005991': 'French',
#  '4788473': 'Japanese',
#  '2637658': 'Chinese',
#  '2143934': 'Japanese',
#  '4853955': 'Chinese',
#  '4820958': 'Thai',
#  '2000749': 'Indian',
#  '2005052': 'Chinese',
#  '2061109': 'Chinese',
#  '4824321': 'Italian',
#  '5073222': 'Chinese',
#  '4816066': 'Japanese',
#  '4823836': 'Chinese',
#  '5080548': 'Italian',
#  '1996222': 'Chinese',
#  '2150506': 'Chinese',
#  '5038480': 'Chinese',
#  '5120072': 'Chinese',
#  '2225674': 'Chinese',
#  '2124192': 'Italian',
#  '4810000': 'Italian',
#  '2151747': 'Chinese',
#  '4807431': 'Chinese',
#  '4821389': 'Chinese',
#  '4851517': 'Chinese',
#  '2239163': 'Chinese',
#  '2062491': 'Chinese',
#  '5134209': 'Modern British',
#  '4845719': 'Modern British',
#  '5158816': 'Modern British',
#  '5407313': 'Modern British',
#  '4996566': 'Modern British',
#  '5134257': 'Modern British',
#  '5162416': 'Modern British',
#  '4850692': 'Modern British',
#  '5060611': 'Modern British',
#  '5135529': 'Modern British',
#  '2029636': 'Chinese',
#  '2074680': 'Chinese',
#  '5006256': 'Chinese',
#  '4834858': 'Chinese',
#  '4815554': 'Italian',
#  '2216804': 'Chinese',
#  '4857335': 'Italian',
#  '4803628': 'Italian',
#  '2030898': 'French',
#  '4835107': 'French',
#  '5040398': 'Chinese',
#  '4806692': 'Chinese',
#  '2201104': 'Chinese',
#  '4820825': 'Chinese',
#  '2289096': 'Chinese',
#  '2073455': 'Chinese',
#  '4835470': 'Chinese',
#  '4857020': 'Chinese',
#  '4828503': 'Chinese',
#  '4834844': 'Chinese',
#  '2023301': 'Italian',
#  '2683946': 'Chinese',
#  '4839911': 'French',
#  '2026022': 'Chinese',
#  '2060276': 'Chinese',
#  '2025784': 'Chinese',
#  '2183843': 'French',
#  '4837936': 'Italian',
#  '4839966': 'Chinese',
#  '2059254': 'Chinese',
#  '4835488': 'French',
#  '4835509': 'Italian',
#  '4833797': 'Italian',
#  '2187875': 'Thai',
#  '2637279': 'French',
#  '4838096': 'Italian',
#  '4839205': 'Italian',
#  '5356957': 'Indian',
#  '5394180': 'Indian',
#  '5369899': 'Indian',
#  '5393079': 'Japanese',
#  '5501056': 'Japanese',
#  '5299727': 'Thai',
#  '5336246': 'Chinese',
#  '5370682': 'Indian',
#  '5370164': 'Indian',
#  '5346174': 'Chinese',
#  '5395224': 'Thai',
#  '5331463': 'Italian',
#  '5394069': 'Chinese',
#  '5387443': 'Chinese',
#  '5329738': 'Indian',
#  '5347972': 'Chinese',
#  '5353225': 'Japanese',
#  '5370695': 'Thai',
#  '5394001': 'Indian',
#  '5353466': 'Japanese',
#  '5392983': 'Chinese',
#  '5392798': 'Indian',
#  '5334138': 'Chinese',
#  '1878656': 'Japanese',
#  '2260049': 'Italian',
#  '5169051': 'Japanese',
#  '4568100': 'Japanese',
#  '1382166': 'Thai',
#  '1025289': 'Chinese',
#  '1833048': 'Italian',
#  '3144790': 'Italian',
#  '1026256': 'Italian',
#  '1078245': 'Italian',
#  '1054721': 'Italian',
#  '1081664': 'Italian',
#  '1075065': 'Japanese',
#  '1062501': 'Japanese',
#  '1076569': 'Italian',
#  '1077969': 'Italian',
#  '1063545': 'Japanese',
#  '1365448': 'Thai',
#  '1062230': 'Italian',
#  '4809934': 'Thai',
#  '1137621': 'Chinese',
#  '5074412': 'French',
#  '5026595': 'Japanese',
#  '1060830': 'Italian',
#  '1328998': 'French',
#  '1150906': 'Japanese',
#  '1076669': 'Thai',
#  '1074182': 'Indian',
#  '1076462': 'Thai',
#  '1827194': 'French',
#  '1076944': 'Italian',
#  '1080159': 'Chinese',
#  '1385170': 'Thai',
#  '5320297': 'Thai',
#  '1062572': 'Chinese',
#  '5331513': 'Japanese',
#  '1054643': 'Indian',
#  '1250600': 'Japanese',
#  '1144491': 'French',
#  '1151888': 'French',
#  '1061040': 'Italian',
#  '1320389': 'Italian',
#  '1072059': 'Japanese',
#  '1210827': 'Italian',
#  '1074355': 'Chinese',
#  '1133292': 'Italian',
#  '1080307': 'Italian',
#  '5069446': 'French',
#  '1144627': 'Italian',
#  '5351968': 'Italian',
#  '1372196': 'French',
#  '5332942': 'French',
#  '1137546': 'French',
#  '1183991': 'Thai',
#  '4899880': 'Modern British',
#  '4800138': 'Modern British',
#  '4785819': 'Italian',
#  '4853595': 'French',
#  '4857850': 'Modern British',
#  '4819626': 'Italian',
#  '4810836': 'Thai',
#  '2010359': 'Thai',
#  '2068375': 'French',
#  '1987215': 'Chinese',
#  '4811026': 'Thai',
#  '5365777': 'Thai',
#  '4684345': 'Thai',
#  '4608636': 'Thai',
#  '2064725': 'Chinese',
#  '2074892': 'Thai',
#  '5087787': 'Thai',
#  '4608683': 'Thai',
#  '4569400': 'Italian',
#  '2105546': 'Thai',
#  '4654953': 'Japanese',
#  '2000643': 'French',
#  '2062718': 'Thai',
#  '4817355': 'Thai',
#  '4645480': 'Thai',
#  '2021424': 'Thai',
#  '2131979': 'Thai',
#  '4572538': 'Thai',
#  '4645462': 'Thai',
#  '2067950': 'Thai',
#  '4807941': 'Thai',
#  '2646706': 'Thai',
#  '2067194': 'Italian',
#  '2010961': 'Thai',
#  '2012377': 'Thai',
#  '4811771': 'Thai',
#  '4604971': 'Thai',
#  '2010836': 'Thai',
#  '2010960': 'Thai',
#  '2010455': 'Thai',
#  '2274762': 'French',
#  '2010357': 'Thai',
#  '4610218': 'Thai',
#  '4540154': 'Thai',
#  '4828959': 'Indian',
#  '2010683': 'Indian',
#  '4584824': 'Italian',
#  '1919034': 'Thai',
#  '4565713': 'Thai',
#  '4811592': 'Thai',
#  '2111981': 'Chinese',
#  '2202305': 'Japanese',
#  '4614049': 'Thai',
#  '2062934': 'Thai',
#  '4576687': 'French',
#  '2000742': 'Italian',
#  '4584752': 'Italian',
#  '4564687': 'Thai',
#  '2095128': 'Indian',
#  '2684691': 'Thai',
#  '2011165': 'Thai',
#  '4810496': 'Thai',
#  '2139347': 'Chinese',
#  '2275631': 'Thai',
#  '2152077': 'Thai',
#  '4584452': 'Thai',
#  '5133173': 'Thai',
#  '4584583': 'Chinese',
#  '2010772': 'Thai',
#  '4770192': 'Chinese',
#  '4808930': 'Thai',
#  '4609151': 'Italian',
#  '2065559': 'Italian',
#  '4819573': 'Thai',
#  '2246951': 'Thai',
#  '2065495': 'Thai',
#  '4590889': 'Thai',
#  '2000645': 'Thai',
#  '2226437': 'Thai',
#  '2068594': 'Italian',
#  '2068458': 'Thai',
#  '2010832': 'Thai',
#  '2011767': 'Thai',
#  '1889731': 'Thai',
#  '2063132': 'Thai',
#  '4967398': 'Thai',
#  '4631985': 'Thai',
#  '4191551': 'Italian',
#  '4585098': 'Thai',
#  '2012649': 'Thai',
#  '4816822': 'Thai',
#  '4807711': 'Thai',
#  '4810744': 'Thai',
#  '2010898': 'Thai',
#  '2078277': 'Thai',
#  '2273605': 'Thai',
#  '2054804': 'Thai',
#  '4827186': 'Thai',
#  '2120616': 'Thai',
#  '4587290': 'French',
#  '4652048': 'Thai',
#  '4807751': 'Thai',
#  '4093247': 'Thai',
#  '4624487': 'Indian',
#  '2272946': 'Chinese',
#  '4865234': 'Thai',
#  '2060336': 'Italian',
#  '2135369': 'Italian',
#  '4594046': 'Thai',
#  '2065219': 'Italian',
#  '1918976': 'Chinese',
#  '2002063': 'Thai',
#  '2073782': 'Japanese',
#  '2059014': 'Thai',
#  '4584265': 'Japanese',
#  '2011223': 'Thai',
#  '5133679': 'Italian',
#  '2059789': 'Thai',
#  '4568954': 'Thai',
#  '4586953': 'Japanese',
#  '2123364': 'Thai',
#  '2063053': 'Japanese',
#  '4594127': 'Thai',
#  '4596309': 'Thai',
#  '2211749': 'Thai',
#  '2226732': 'Italian',
#  '4755828': 'Thai',
#  '4856400': 'Indian',
#  '2067195': 'Chinese',
#  '2012700': 'Thai',
#  '4563900': 'Thai',
#  '2065270': 'Japanese',
#  '2143184': 'Thai',
#  '2068302': 'Italian',
#  '4619685': 'Thai',
#  '2078561': 'Thai',
#  '2157642': 'Thai',
#  '2057603': 'Thai',
#  '2123919': 'Thai',
#  '4964626': 'Thai',
#  '4537064': 'Chinese',
#  '2058602': 'Thai',
#  '2056614': 'French',
#  '4571687': 'Italian',
#  '2068381': 'Thai',
#  '2064622': 'Thai',
#  '5304521': 'Japanese',
#  '5125026': 'Japanese',
#  '5170370': 'Japanese',
#  '5341416': 'Japanese',
#  '4654352': 'Japanese',
#  '5022368': 'Japanese',
#  '5307027': 'Italian',
#  '4494124': 'Japanese',
#  '5124043': 'Indian',
#  '4156064': 'Japanese',
#  '4750051': 'French',
#  '1264053': 'French',
#  '1947364': 'Italian',
#  '1403627': 'Japanese',
#  '5382143': 'Japanese',
#  '4655726': 'Japanese',
#  '2639635': 'Italian',
#  '4602428': 'Japanese',
#  '4579777': 'Japanese',
#  '1365442': 'French',
#  '1418077': 'Japanese',
#  '1384124': 'Japanese',
#  '1253496': 'Japanese',
#  '1278094': 'Japanese',
#  '1947908': 'Japanese',
#  '1207692': 'Japanese',
#  '4647457': 'Italian',
#  '1211452': 'Japanese',
#  '4588418': 'Indian',
#  '4504577': 'Japanese',
#  '1176481': 'Japanese',
#  '1166439': 'French',
#  '1128281': 'Japanese',
#  '1423069': 'Japanese',
#  '4584860': 'Japanese',
#  '1024025': 'Japanese',
#  '4586452': 'Japanese',
#  '5499980': 'Japanese',
#  '4599795': 'Japanese',
#  '1024860': 'Japanese',
#  '2093296': 'Italian',
#  '4169237': 'Japanese',
#  '1171697': 'Chinese',
#  '1171129': 'Japanese',
#  '4582729': 'Italian',
#  '1827319': 'Japanese',
#  '1274517': 'Japanese',
#  '1196710': 'Japanese',
#  '4974914': 'French',
#  '4512872': 'Japanese',
#  '1180795': 'Japanese',
#  '1004760': 'Japanese',
#  '5160387': 'Chinese',
#  '4640818': 'Indian',
#  '5342993': 'French',
#  '1871813': 'Japanese',
#  '2027609': 'French',
#  '1899609': 'French',
#  '1870554': 'Japanese',
#  '4640252': 'Japanese',
#  '5337009': 'Chinese',
#  '4853159': 'French',
#  '5361882': 'Japanese',
#  '2638195': 'French',
#  '2021556': 'French',
#  '1893112': 'French',
#  '4641053': 'French',
#  '1889703': 'Japanese',
#  '2241093': 'Japanese',
#  '2028310': 'Japanese',
#  '2288867': 'French',
#  '2014890': 'Japanese',
#  '2158231': 'Indian',
#  '4654733': 'French',
#  '2096521': 'Japanese',
#  '2147438': 'Italian',
#  '4898123': 'Italian',
#  '1891295': 'French',
#  '5350236': 'Japanese',
#  '5337244': 'Chinese',
#  '2168112': 'Japanese',
#  '4680107': 'French',
#  '1889886': 'Italian',
#  '4680240': 'Italian',
#  '2130310': 'Italian',
#  '4853106': 'Japanese',
#  '4686584': 'Japanese',
#  '2029184': 'Italian',
#  '5156763': 'Italian',
#  '5317917': 'French',
#  '2022919': 'Italian',
#  '4660380': 'Italian',
#  '5313710': 'Chinese',
#  '4669928': 'French',
#  '5455736': 'French',
#  '1991202': 'Japanese',
#  '1990067': 'Indian',
#  '2202039': 'Chinese',
#  '2636678': 'Chinese',
#  '5160105': 'Japanese',
#  '4848440': 'Japanese',
#  '2141375': 'Japanese',
#  '1895905': 'Chinese',
#  '2269228': 'Chinese',
#  '2224981': 'Japanese',
#  '5318176': 'Italian',
#  '5318287': 'French',
#  '4640900': 'French',
#  '1889141': 'Japanese',
#  '1899607': 'French',
#  '4684255': 'Japanese',
#  '4647086': 'French',
#  '5362277': 'Japanese',
#  '5156292': 'French',
#  '5155781': 'Japanese',
#  '1899550': 'French',
#  '4838581': 'Japanese',
#  '4855566': 'Japanese',
#  '4853003': 'Japanese',
#  '2700866': 'Japanese',
#  '2051004': 'French',
#  '2022975': 'Japanese',
#  '2284693': 'French',
#  '2146711': 'French',
#  '2230410': 'Italian',
#  '2081113': 'Italian',
#  '1990634': 'French',
#  '4653919': 'Japanese',
#  '4675558': 'Chinese',
#  '2019754': 'French',
#  '2028977': 'French',
#  '5336859': 'Japanese',
#  '5318737': 'Japanese',
#  '5342690': 'Japanese',
#  '5342543': 'Japanese',
#  '5313752': 'Italian',
#  '4637405': 'Japanese',
#  '1889892': 'French',
#  '2646046': 'French',
#  '2241541': 'French',
#  '1893427': 'Japanese',
#  '5337325': 'Japanese',
#  '5156051': 'French',
#  '5156005': 'Japanese',
#  '5155917': 'Japanese',
#  '5337075': 'French',
#  '1889056': 'French',
#  '2130458': 'Japanese',
#  '2685442': 'Japanese',
#  '4670311': 'French',
#  '1991093': 'Japanese',
#  '2139678': 'Japanese',
#  '1990854': 'Japanese',
#  '4650894': 'French',
#  '5313819': 'French',
#  '4637012': 'French',
#  '1896134': 'Chinese',
#  '1888995': 'French',
#  '1899612': 'French',
#  '1892122': 'French',
#  '4666011': 'Italian',
#  '2164081': 'French',
#  '1896813': 'Japanese',
#  '4841394': 'Japanese',
#  '2027373': 'French',
#  '4900926': 'Japanese',
#  '5157010': 'Japanese',
#  '5341736': 'Italian',
#  '1889205': 'Japanese',
#  '4855612': 'Japanese',
#  '4685212': 'Japanese',
#  '2697904': 'French',
#  '1889844': 'Japanese',
#  '4645144': 'French',
#  '2096522': 'French',
#  '5362241': 'Japanese',
#  '2683883': 'French',
#  '1896034': 'Chinese',
#  '2122893': 'Italian',
#  '5160303': 'Chinese',
#  '5155479': 'French',
#  '1871636': 'Japanese',
#  '4636756': 'French',
#  '2197549': 'French',
#  '2209793': 'French',
#  '4643889': 'Japanese',
#  '2643355': 'Japanese',
#  '1991205': 'Japanese',
#  '4901153': 'Japanese',
#  '1895801': 'Chinese',
#  '2698912': 'Japanese',
#  '2191241': 'Chinese',
#  '5349552': 'Japanese',
#  '1896255': 'Japanese',
#  '5522607': 'Italian',
#  '4666087': 'French',
#  '2288031': 'Japanese',
#  '2264615': 'Japanese',
#  '2079952': 'Japanese',
#  '1870288': 'French',
#  '4855336': 'Japanese',
#  '2027750': 'Japanese',
#  '1871809': 'Chinese',
#  '2112200': 'French',
#  '1896252': 'Japanese',
#  '4841472': 'French',
#  '1871404': 'Japanese',
#  '4654989': 'French',
#  '4855520': 'Japanese',
#  '2267778': 'French',
#  '1990289': 'Italian',
#  '4675728': 'Chinese',
#  '2272822': 'Chinese',
#  '1990064': 'French',
#  '2022740': 'French',
#  '2022922': 'French',
#  '1890471': 'Japanese',
#  '2023042': 'French',
#  '1889295': 'Japanese',
#  '1892126': 'French',
#  '2699212': 'Italian',
#  '2148965': 'Japanese',
#  '2149039': 'Italian',
#  '1889950': 'French',
#  '4686492': 'Japanese',
#  '2102011': 'French',
#  '1890467': 'Japanese',
#  '1990542': 'Italian',
#  '1889382': 'French',
#  '1889405': 'French',
#  '2231064': 'Japanese',
#  '4852871': 'Japanese',
#  '4933143': 'Japanese',
#  '2232938': 'French',
#  '2128002': 'French',
#  '2113451': 'Japanese',
#  '2299740': 'Japanese',
#  '1893125': 'Italian',
#  '5361746': 'Japanese',
#  '4848322': 'Japanese',
#  '2636277': 'Japanese',
#  '1896809': 'Japanese',
#  '2278254': 'French',
#  '4933461': 'French',
#  '2022861': 'French',
#  '1871048': 'French',
#  '4838816': 'Japanese',
#  '5361845': 'Japanese',
#  '1871629': 'Italian',
#  '2178865': 'French',
#  '1871103': 'Japanese',
#  '1893457': 'French',
#  '2081229': 'Japanese',
#  '2644581': 'Japanese',
#  '4841431': 'Japanese',
#  '4709420': 'French',
#  '1990184': 'Japanese',
#  '3165878': 'French',
#  '2277255': 'Italian',
#  '2009224': 'Italian',
#  '2247757': 'French',
#  '2081107': 'French',
#  '1871782': 'Japanese',
#  '4787887': 'Japanese',
#  '2079957': 'Japanese',
#  '1900097': 'Chinese',
#  '4855481': 'Japanese',
#  '5624234': 'French',
#  '2637221': 'Japanese',
#  '4838766': 'French',
#  '5350644': 'Japanese',
#  '2685863': 'French',
#  '2209236': 'Japanese',
#  '4852854': 'Japanese',
#  '1893813': 'Japanese',
#  '2261232': 'Chinese',
#  '4787826': 'Japanese',
#  '4638636': 'French',
#  '1871433': 'Japanese',
#  '1890092': 'Chinese',
#  '2200948': 'French',
#  '4686690': 'Japanese',
#  '1896246': 'Japanese',
#  '1869441': 'French',
#  '3167546': 'French',
#  '2022736': 'French',
#  '2048448': 'French',
#  '2690581': 'Japanese',
#  '1889172': 'French',
#  '1896364': 'Japanese',
#  '1896040': 'Chinese',
#  '1889377': 'Japanese',
#  '4961816': 'Italian',
#  '2022797': 'Italian',
#  '2021629': 'Chinese',
#  '1889406': 'French',
#  '2645000': 'Japanese',
#  '2271719': 'Chinese',
#  '1896256': 'Japanese',
#  '4662126': 'Italian',
#  '5362157': 'Japanese',
#  '5349898': 'Japanese',
#  '2645694': 'Japanese',
#  '1896805': 'Japanese',
#  '2104810': 'Japanese',
#  '5027479': 'Indian',
#  '5076707': 'Italian',
#  '5113578': 'Italian',
#  '5120196': 'Indian',
#  '5088609': 'French',
#  '5380786': 'Italian',
#  '5152638': 'Chinese',
#  '5034734': 'Indian',
#  '5140574': 'French',
#  '5040654': 'Chinese',
#  '5372293': 'Thai',
#  '5067459': 'Italian',
#  '5024914': 'Indian',
#  '5027018': 'Chinese',
#  '4895485': 'Chinese',
#  '5161446': 'Italian',
#  '5311237': 'Chinese',
#  '5218812': 'Thai',
#  '4928891': 'Italian',
#  '4807292': 'Japanese',
#  '4600067': 'Japanese',
#  '474124': 'Japanese',
#  '754673': 'French',
#  '5504495': 'Italian',
#  '759302': 'Italian',
#  '259717': 'Italian',
#  '1938529': 'Japanese',
#  '5152220': 'Italian',
#  '5159969': 'Chinese',
#  '2007975': 'Italian',
#  '4633812': 'Chinese',
#  '4846190': 'Japanese',
#  '4856132': 'Italian',
#  '4764258': 'Modern British',
#  '4787451': 'Modern British',
#  '4851147': 'Modern British',
#  '5165759': 'Modern British',
#  '4023727': 'French',
#  '5513677': 'French',
#  '3924985': 'Italian',
#  '2241860': 'Italian',
#  '2288564': 'Italian',
#  '2133874': 'French',
#  '2170432': 'Thai',
#  '2090482': 'Japanese',
#  '2150224': 'Japanese',
#  '2280423': 'Thai',
#  '2182675': 'Italian',
#  '4614955': 'Chinese',
#  '2216755': 'Italian',
#  '1912362': 'Japanese',
#  '4828348': 'Italian',
#  '4156552': 'Italian',
#  '1948718': 'Thai',
#  '2125293': 'Italian',
#  '4630569': 'Italian',
#  '2285681': 'French',
#  '1953113': 'Italian',
#  '2141571': 'Italian',
#  '2098400': 'Italian',
#  '1950207': 'Japanese',
#  '2161527': 'Japanese',
#  '1912368': 'Italian',
#  '2123786': 'Italian',
#  '1952415': 'Japanese',
#  '2284060': 'Japanese',
#  '5474191': 'Italian',
#  '4614770': 'Italian',
#  '1948583': 'French',
#  '4028122': 'French',
#  '4774153': 'Italian',
#  '4876321': 'Indian',
#  '4866516': 'Italian',
#  '4845348': 'Italian',
#  '4873841': 'Italian',
#  '1999237': 'French',
#  '1893488': 'Japanese',
#  '2014269': 'French',
#  '4861938': 'French',
#  '2006647': 'Italian',
#  '2014195': 'French',
#  '4862872': 'French',
#  '4863495': 'French',
#  '2214891': 'French',
#  '4851739': 'Japanese',
#  '4870025': 'French',
#  '4861703': 'Italian',
#  '2007516': 'Chinese',
#  '2003472': 'French',
#  '4895731': 'Japanese',
#  '2005842': 'Japanese',
#  '4853688': 'French',
#  '2007402': 'Italian',
#  '2002207': 'Japanese',
#  '1999350': 'Thai',
#  '2641116': 'Chinese',
#  '4865571': 'Italian',
#  '2018522': 'Italian',
#  '1999715': 'Japanese',
#  '4874012': 'Thai',
#  '4857774': 'Japanese',
#  '4870716': 'Japanese',
#  '2155009': 'French',
#  '2114741': 'Japanese',
#  '2002348': 'Chinese',
#  '2218146': 'Japanese',
#  '4878258': 'Chinese',
#  '2643255': 'Chinese',
#  '2214819': 'Chinese',
#  '2250223': 'Italian',
#  '4863468': 'French',
#  '4849568': 'French',
#  '4908462': 'French',
#  '2180166': 'French',
#  '4861875': 'Chinese',
#  '1993390': 'Chinese',
#  '4870780': 'French',
#  '2235265': 'French',
#  '1998853': 'Japanese',
#  '1993534': 'Japanese',
#  '2215152': 'Thai',
#  '5075345': 'Japanese',
#  '4857948': 'Thai',
#  '5152131': 'Italian',
#  '4761801': 'Italian',
#  '1083006': 'Thai',
#  '1018822': 'French',
#  '4758646': 'Italian',
#  '1281215': 'Japanese',
#  '4218664': 'Indian',
#  '1170395': 'Thai',
#  '1358392': 'Thai',
#  '1170523': 'Indian',
#  '4777813': 'Thai',
#  '1099106': 'Italian',
#  '1055845': 'Thai',
#  '4509903': 'French',
#  '4712984': 'Italian',
#  '1324685': 'Italian',
#  '1098223': 'French',
#  '1056753': 'Indian',
#  '1332648': 'Thai',
#  '1163237': 'Italian',
#  '4769731': 'Italian',
#  '1128278': 'Italian',
#  '5414138': 'Italian',
#  '4769918': 'Italian',
#  '4712565': 'Italian',
#  '4972408': 'Italian',
#  '4769541': 'Italian',
#  '1236911': 'French',
#  '4974031': 'Indian',
#  '1163452': 'Italian',
#  '1093381': 'Italian',
#  '4819095': 'Italian',
#  '1174401': 'Indian',
#  '5127400': 'Italian',
#  '1092516': 'Thai',
#  '4779925': 'French',
#  '4973398': 'Italian',
#  '5529668': 'Italian',
#  '4797456': 'Italian',
#  '1272319': 'French',
#  '4769046': 'French',
#  '1370748': 'Japanese',
#  '4510729': 'Indian',
#  '4831309': 'Italian',
#  '4406359': 'Italian',
#  '4665904': 'Japanese',
#  '5122298': 'Japanese',
#  '5081643': 'Japanese',
#  '5081528': 'Italian',
#  '2140790': 'Japanese',
#  '1991655': 'Japanese',
#  '2080653': 'Japanese',
#  '1920474': 'Japanese',
#  '4558793': 'Japanese',
#  '2292304': 'Japanese',
#  '4552277': 'Japanese',
#  '4552193': 'Japanese',
#  '5082345': 'Japanese',
#  '1919903': 'Japanese',
#  '4531253': 'Japanese',
#  '2155251': 'Japanese',
#  '1899881': 'Japanese',
#  '2083780': 'Japanese',
#  '2645693': 'Japanese',
#  '4540733': 'French',
#  '2080998': 'Japanese',
#  '1918934': 'Italian',
#  '2187354': 'Japanese',
#  '4568136': 'French',
#  '2039252': 'Japanese',
#  '2142631': 'Japanese',
#  '2238258': 'Chinese',
#  '2084436': 'Japanese',
#  '2199143': 'Japanese',
#  '2190757': 'Italian',
#  '4555276': 'Chinese',
#  '2209232': 'Japanese',
#  '2090818': 'Japanese',
#  '2249769': 'Japanese',
#  '4535711': 'Japanese',
#  '1916402': 'Japanese',
#  '2141377': 'Japanese',
#  '2183256': 'Japanese',
#  '5087538': 'Chinese',
#  '5118916': 'Japanese',
#  '2299735': 'Chinese',
#  '2079838': 'Japanese',
#  '2189540': 'Japanese',
#  '2128127': 'Japanese',
#  ...}

# %%
# test reading an image
#folder_path = '/Users/wentingjiang/Downloads/assignment2/images'
#image_path=folder_path + '/' + image_names[0] + '.jpg'
#img=Image.open(image_path)
#img

# %%
# reading all images in a restaurant setting  (for relevant cuisines)
all_images={}
folder_path = '/Users/wentingjiang/Downloads/assignment2/images'
target_size = (128, 128) # use smaller size to make computation more efficient

for name in image_names:
    file_name=name + '.jpg'
    image_path = folder_path + '/' + file_name
    try:
        with Image.open(image_path) as img:
            img = img.resize(target_size)
            image_array = np.array(img)
            if image_array.shape == (128, 128, 3):
                all_images[name]=image_array
            #print(name)
    except:
        print(f"Error opening file '{file_name}', skipping...")
        continue

# %%
#plt.imshow(all_images['1955140'], cmap='gray')
#plt.show() # quality of 64x64 becomes much worse

# %%
test_image_list=[]
test_image_names=[]
test_labels=[]
for i in all_images: 
    test_image_list.append(all_images[i])
    test_image_names.append(i)
    test_labels.append(image_id_label[i])

# %%
test=np.array(test_image_list)
test.shape
# Out:
# (2202, 128, 128, 3)

# %%
import keras
# Out:
# 2023-05-05 23:08:55.406077: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Filter out non-food images

# %%
loc='/Users/wentingjiang/Downloads/assignment2/'
# path to the folder containing the JSON files
folder_path = loc+'labels/'
# get a list of all the files in the folder
file_list = os.listdir(folder_path)

label_dict={}
# iterate over the files
for file_name in file_list:
    # check if the file is a JSON file
    if file_name.endswith('.json'):
        # construct the full path to the file
        file_path = os.path.join(folder_path, file_name)
        # open the file and read its contents
        with open(file_path, 'r') as file:
            json_data = json.load(file)        
        txt=json_data['imagePath']
        image_id=txt.split(".")[0]
        label_dict[image_id]=int(json_data['flags']['food'])
        print(json_data)
# Out:
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234812.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241912.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241857.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 750}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '213777.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214548.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233791.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '243169.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234392.jpg', 'imageData': None, 'imageHeight': 665, 'imageWidth': 665}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241338.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215836.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '235079.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214374.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241945.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234453.jpg', 'imageData': None, 'imageHeight': 666, 'imageWidth': 666}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234003.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215477.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '242543.jpg', 'imageData': None, 'imageHeight': 1080, 'imageWidth': 1080}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233400.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '232987.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '216021.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214159.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215748.jpg', 'imageData': None, 'imageHeight': 667, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '243082.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '232712.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234629.jpg', 'imageData': None, 'imageHeight': 2001, 'imageWidth': 2001}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '243344.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '213809.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233945.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '216076.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233768.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '243190.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 858}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '232895.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233857.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '232745.jpg', 'imageData': None, 'imageHeight': 563, 'imageWidth': 563}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233912.jpg', 'imageData': None, 'imageHeight': 1080, 'imageWidth': 1080}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215089.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233011.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215573.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215334.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '232417.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215271.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241586.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234486.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233969.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '232381.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234605.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215363.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '243016.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '242607.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241617.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234428.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233617.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '242304.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214134.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214071.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234097.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 667}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241197.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215660.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214972.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '242538.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '235055.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '213864.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241314.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '243283.jpg', 'imageData': None, 'imageHeight': 1080, 'imageWidth': 1080}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241251.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '213921.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '235110.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '213472.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214163.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215267.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233705.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241969.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234243.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241343.jpg', 'imageData': None, 'imageHeight': 1080, 'imageWidth': 1080}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '242095.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234756.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234306.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214397.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 750}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215093.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215569.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241764.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214401.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '232533.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215355.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241158.jpg', 'imageData': None, 'imageHeight': 563, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '232476.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215928.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '213956.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215181.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241733.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '243077.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': True}, 'shapes': [], 'imagePath': '232837.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214456.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '242723.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215752.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234330.jpg', 'imageData': None, 'imageHeight': 665, 'imageWidth': 665}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '235171.jpg', 'imageData': None, 'imageHeight': 750, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214339.jpg', 'imageData': None, 'imageHeight': 1365, 'imageWidth': 1365}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '243348.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241375.jpg', 'imageData': None, 'imageHeight': 1080, 'imageWidth': 1080}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215482.jpg', 'imageData': None, 'imageHeight': 1080, 'imageWidth': 1080}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233699.jpg', 'imageData': None, 'imageHeight': 2848, 'imageWidth': 2848}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215601.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234449.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241549.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214155.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234367.jpg', 'imageData': None, 'imageHeight': 666, 'imageWidth': 666}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214944.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 781}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215656.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214102.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214552.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '242060.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233820.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214250.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '243108.jpg', 'imageData': None, 'imageHeight': 716, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '232620.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233461.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '242934.jpg', 'imageData': None, 'imageHeight': 667, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '242037.jpg', 'imageData': None, 'imageHeight': 1080, 'imageWidth': 1080}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241162.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234961.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233318.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214968.jpg', 'imageData': None, 'imageHeight': 750, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234127.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215115.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '232266.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '216105.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214138.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '235235.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234424.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241461.jpg', 'imageData': None, 'imageHeight': 667, 'imageWidth': 667}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233973.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '216294.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233070.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214246.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215904.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '216017.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214883.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241436.jpg', 'imageData': None, 'imageHeight': 667, 'imageWidth': 667}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241821.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 750}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '213351.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '216016.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215840.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215513.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233134.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214247.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '235234.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241525.jpg', 'imageData': None, 'imageHeight': 562, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234425.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215544.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '232267.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 718}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215694.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234063.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234960.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '216112.jpg', 'imageData': None, 'imageHeight': 658, 'imageWidth': 658}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': True, 'other': False}, 'shapes': [], 'imagePath': '214969.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '232621.jpg', 'imageData': None, 'imageHeight': 4128, 'imageWidth': 4128}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233460.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '242718.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 835}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '213717.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '243109.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234872.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '213652.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '213982.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234608.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215505.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '242124.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214314.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '242061.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '213594.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214251.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215207.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233765.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214046.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234809.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '242276.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214103.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '232898.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234366.jpg', 'imageData': None, 'imageHeight': 665, 'imageWidth': 665}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234389.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214695.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214011.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233677.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215745.jpg', 'imageData': None, 'imageHeight': 667, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215895.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '213412.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '213804.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234274.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215483.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215179.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233374.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '242667.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '232565.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '242722.jpg', 'imageData': None, 'imageHeight': 750, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215753.jpg', 'imageData': None, 'imageHeight': 667, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': True, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215303.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215929.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241677.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 750}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '235023.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# ...
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '242452.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234450.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241550.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234000.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '243078.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233403.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '242813.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '242540.jpg', 'imageData': None, 'imageHeight': 563, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215927.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234329.jpg', 'imageData': None, 'imageHeight': 668, 'imageWidth': 668}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234779.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '216022.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215177.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '243347.jpg', 'imageData': None, 'imageHeight': 800, 'imageWidth': 800}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215931.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214789.jpg', 'imageData': None, 'imageHeight': 641, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '232711.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '235200.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '216075.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233012.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215570.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215989.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214731.jpg', 'imageData': None, 'imageHeight': 1365, 'imageWidth': 1365}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214224.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233854.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241792.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241638.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215272.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241585.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214463.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 750}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '213719.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '232414.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '216262.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241643.jpg', 'imageData': None, 'imageHeight': 667, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241706.jpg', 'imageData': None, 'imageHeight': 667, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234606.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '232382.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214434.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234128.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '243015.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233317.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214822.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215360.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241614.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '232290.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234094.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241194.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '215663.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214072.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214137.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '242184.jpg', 'imageData': None, 'imageHeight': 1603, 'imageWidth': 1603}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '235113.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '213471.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233497.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234217.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '242868.jpg', 'imageData': None, 'imageHeight': 667, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '213534.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '235056.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '216018.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234539.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '233706.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234755.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '234305.jpg', 'imageData': None, 'imageHeight': 668, 'imageWidth': 668}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '214249.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}
# {'version': '5.1.1', 'flags': {'food': False, 'restaurant': True, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '242096.jpg', 'imageData': None, 'imageHeight': 667, 'imageWidth': 667}
# {'version': '5.1.1', 'flags': {'food': True, 'restaurant': False, 'logo': False, 'chef': False, 'food_preparation': False, 'other': False}, 'shapes': [], 'imagePath': '241340.jpg', 'imageData': None, 'imageHeight': 1000, 'imageWidth': 1000}

# %%
# just use the previous model to predict and see the outcome

image_names_test=list(label_dict.keys())
image_labels_test=list(label_dict.values())

# reading all images in a restaurant setting 
#all_test_images={}
folder_path = loc+'images'
target_size = (128, 128) # need to resize because some images do not have the same shap

# read all
test_label=[]
new_test_image_list= []
for ind,name in enumerate(image_names_test):
    file_name=name + '.jpg'
    image_path = folder_path + '/' + file_name
    try:
        with Image.open(image_path) as img:
            img = img.resize(target_size)
            image_array = np.array(img)
            #all_test_images[name]=image_array       
            new_test_image_list.append(image_array)
            test_label.append(image_labels_test[ind])
            #print(name)
    except:
        print(f"Error opening file '{file_name}', skipping...")
        continue

print('read ' + str(len(new_test_image_list)) + ' images')

sum(test_label)/len(test_label)
# there is a slight issue of class imbalance, accuracy is not be the best metric
# Out:
# read 1184 images
# 0.6613175675675675

# %%
new_test=np.array(new_test_image_list)
new_test.shape
# Out:
# (1184, 128, 128, 3)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    new_test, np.array(test_label), test_size=0.2, stratify=np.array(test_label), random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# %%
class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique(y_train),
                                        y = y_train                                                    
                                    )
class_weights = dict(zip(np.unique(y_train), class_weights))
class_weights
# Out:
# {0: 1.4750778816199377, 1: 0.7563897763578274}

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.applications import VGG16
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# Load the pre-trained model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

# Freeze pre-trained layers (compare with no freezing)
for layer in base_model.layers:
    layer.trainable = False
    
early_stopping = EarlyStopping(monitor='val_loss', patience=2)


# Define your own classification layers
model = Sequential()
model.add(base_model)
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))


learning_rate = 0.001 # or any other value you want to try
adam = Adam(learning_rate=learning_rate)

# Compile the model
model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_2 (Dense)             (None, 128)               1048704
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 15,763,521
# Trainable params: 1,048,833
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# Train the model
history=model.fit(X_train, y_train, class_weight=class_weights, 
                  epochs=5, batch_size=32, validation_data=(X_test, y_test),
                    callbacks=[early_stopping])

# Evaluate the model on test set
#score = model.evaluate(X_test, y_test)
#print('Test accuracy:', score[1])
# Out:
# Epoch 1/5
# 30/30 [==============================] - 57s 2s/step - loss: 3.5662 - accuracy: 0.9155 - val_loss: 0.6041 - val_accuracy: 0.9747
# Epoch 2/5
# 30/30 [==============================] - 71s 2s/step - loss: 0.0935 - accuracy: 0.9884 - val_loss: 0.3170 - val_accuracy: 0.9831
# Epoch 3/5
# 30/30 [==============================] - 67s 2s/step - loss: 0.0145 - accuracy: 0.9947 - val_loss: 0.3329 - val_accuracy: 0.9789
# Epoch 4/5
# 30/30 [==============================] - 74s 3s/step - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.3403 - val_accuracy: 0.9831

# %%
model.save("my_model.h5")

# %%
# Load the model
model = load_model("my_model.h5")

# %%
# plot loss curve
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='validation loss')
plt.legend()
plt.show()

# %%
import pandas as pd
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam, SGD, Adagrad, RMSprop

# Define a list of hyperparameters to try
learning_rates = [0.001, 0.0001]
optimizers = [Adam, SGD, Adagrad, RMSprop]
batch_sizes = [32, 64, 128]
dropout_rates = [0.1, 0.2]
num_hidden_layers = [1, 2]
activation_functions = ['relu', 'sigmoid']

# Create an empty DataFrame to store the results
results_df = pd.DataFrame(columns=['learning_rate', 'optimizer', 'batch_size', 'dropout_rate', 'num_hidden_layers', 'activation_function', 'val_accuracy', 'history'])

# Loop over all combinations of hyperparameters
for lr in learning_rates:
    for opt in optimizers:
        for bs in batch_sizes:
            for dr in dropout_rates:
                for nl in num_hidden_layers:
                    for act in activation_functions:
                        # Load the pre-trained model
                        base_model = VGG16(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

                        # Freeze pre-trained layers (compare with no freezing)
                        for layer in base_model.layers:
                            layer.trainable = False

                        early_stopping = EarlyStopping(monitor='val_loss', patience=2)

                        # Define your own classification layers
                        model = Sequential()
                        model.add(base_model)
                        model.add(Flatten())
                        for i in range(nl):
                            model.add(Dense(128, activation=act))
                            model.add(Dropout(dr))
                        model.add(Dense(1, activation='sigmoid'))

                        # Compile the model
                        optimizer = opt(learning_rate=lr)
                        model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

                        # Train the model and save the validation accuracy and history
                        history = model.fit(X_train, y_train, class_weight=class_weights, epochs=10, batch_size=bs, validation_data=(X_test, y_test), callbacks=[early_stopping])
                        val_accuracy = history.history['val_accuracy'][-1]

                        # Append the results to the DataFrame
                        my_dict ={'learning_rate': lr, 'optimizer': opt.__name__, 'batch_size': 
 bs, 'dropout_rate': dr, 'num_hidden_layers': nl, 'activation_function': act, 'val_accuracy': val_accuracy, 'history': history}           

                        temp = pd.DataFrame.from_dict(my_dict, orient='index').T
                        results_df = pd.concat([results_df, temp], ignore_index=True)
                        
# Print the results
print(results_df)
# Out:
# Epoch 1/10
# 30/30 [==============================] - 54s 2s/step - loss: 2.3327 - accuracy: 0.9250 - val_loss: 0.4380 - val_accuracy: 0.9662
# Epoch 2/10
# 30/30 [==============================] - 79s 3s/step - loss: 0.2579 - accuracy: 0.9778 - val_loss: 0.3647 - val_accuracy: 0.9789
# Epoch 3/10
# 30/30 [==============================] - 76s 3s/step - loss: 0.0656 - accuracy: 0.9926 - val_loss: 0.2829 - val_accuracy: 0.9831
# Epoch 4/10
# 30/30 [==============================] - 81s 3s/step - loss: 0.0024 - accuracy: 0.9989 - val_loss: 0.3143 - val_accuracy: 0.9831
# Epoch 5/10
# 30/30 [==============================] - 97s 3s/step - loss: 1.6969e-04 - accuracy: 1.0000 - val_loss: 0.3330 - val_accuracy: 0.9789
# Epoch 1/10
# 30/30 [==============================] - 91s 3s/step - loss: 0.1526 - accuracy: 0.9609 - val_loss: 0.0687 - val_accuracy: 0.9789
# Epoch 2/10
# 30/30 [==============================] - 100s 3s/step - loss: 0.0978 - accuracy: 0.9747 - val_loss: 0.0638 - val_accuracy: 0.9873
# Epoch 3/10
# 30/30 [==============================] - 91s 3s/step - loss: 0.0760 - accuracy: 0.9799 - val_loss: 0.0613 - val_accuracy: 0.9831
# Epoch 4/10
# 30/30 [==============================] - 86s 3s/step - loss: 0.0714 - accuracy: 0.9820 - val_loss: 0.0670 - val_accuracy: 0.9831
# Epoch 5/10
# 30/30 [==============================] - 86s 3s/step - loss: 0.0636 - accuracy: 0.9831 - val_loss: 0.0700 - val_accuracy: 0.9831
# Epoch 1/10
# 30/30 [==============================] - 111s 4s/step - loss: 1.4792 - accuracy: 0.9197 - val_loss: 0.2927 - val_accuracy: 0.9789
# Epoch 2/10
# 30/30 [==============================] - 114s 4s/step - loss: 0.2343 - accuracy: 0.9789 - val_loss: 0.5168 - val_accuracy: 0.9831
# Epoch 3/10
# 30/30 [==============================] - 133s 4s/step - loss: 0.1654 - accuracy: 0.9884 - val_loss: 0.5345 - val_accuracy: 0.9789
# Epoch 1/10
# 30/30 [==============================] - 132s 4s/step - loss: 0.2780 - accuracy: 0.9271 - val_loss: 0.0892 - val_accuracy: 0.9873
# Epoch 2/10
# 30/30 [==============================] - 98s 3s/step - loss: 0.1050 - accuracy: 0.9768 - val_loss: 0.0707 - val_accuracy: 0.9873
# Epoch 3/10
# 30/30 [==============================] - 104s 3s/step - loss: 0.0890 - accuracy: 0.9799 - val_loss: 0.0692 - val_accuracy: 0.9873
# Epoch 4/10
# 30/30 [==============================] - 105s 4s/step - loss: 0.0807 - accuracy: 0.9831 - val_loss: 0.0674 - val_accuracy: 0.9873
# Epoch 5/10
# 30/30 [==============================] - 111s 4s/step - loss: 0.0698 - accuracy: 0.9820 - val_loss: 0.0668 - val_accuracy: 0.9873
# Epoch 6/10
# 30/30 [==============================] - 115s 4s/step - loss: 0.0695 - accuracy: 0.9863 - val_loss: 0.0651 - val_accuracy: 0.9873
# Epoch 7/10
# 30/30 [==============================] - 79s 3s/step - loss: 0.0628 - accuracy: 0.9873 - val_loss: 0.0646 - val_accuracy: 0.9873
# Epoch 8/10
# 30/30 [==============================] - 78s 3s/step - loss: 0.0583 - accuracy: 0.9873 - val_loss: 0.0673 - val_accuracy: 0.9873
# Epoch 9/10
# 30/30 [==============================] - 79s 3s/step - loss: 0.0569 - accuracy: 0.9873 - val_loss: 0.0692 - val_accuracy: 0.9873
# Epoch 1/10
# 30/30 [==============================] - 80s 3s/step - loss: 3.9466 - accuracy: 0.9155 - val_loss: 0.3668 - val_accuracy: 0.9873
# Epoch 2/10
# 30/30 [==============================] - 84s 3s/step - loss: 0.2629 - accuracy: 0.9842 - val_loss: 0.2646 - val_accuracy: 0.9831
# Epoch 3/10
# 30/30 [==============================] - 87s 3s/step - loss: 0.0140 - accuracy: 0.9937 - val_loss: 0.3215 - val_accuracy: 0.9705
# Epoch 4/10
# 30/30 [==============================] - 79s 3s/step - loss: 0.0113 - accuracy: 0.9958 - val_loss: 0.3315 - val_accuracy: 0.9705
# Epoch 1/10
# 30/30 [==============================] - 85s 3s/step - loss: 0.2413 - accuracy: 0.9282 - val_loss: 0.0831 - val_accuracy: 0.9789
# Epoch 2/10
# 30/30 [==============================] - 88s 3s/step - loss: 0.1029 - accuracy: 0.9768 - val_loss: 0.0730 - val_accuracy: 0.9831
# Epoch 3/10
# 30/30 [==============================] - 74s 2s/step - loss: 0.0872 - accuracy: 0.9789 - val_loss: 0.0711 - val_accuracy: 0.9831
# Epoch 4/10
# 30/30 [==============================] - 92s 3s/step - loss: 0.0755 - accuracy: 0.9799 - val_loss: 0.0733 - val_accuracy: 0.9831
# Epoch 5/10
# 30/30 [==============================] - 80s 3s/step - loss: 0.0681 - accuracy: 0.9842 - val_loss: 0.0721 - val_accuracy: 0.9789
# Epoch 1/10
# 30/30 [==============================] - 78s 3s/step - loss: 1.5764 - accuracy: 0.9134 - val_loss: 0.6005 - val_accuracy: 0.9662
# Epoch 2/10
# 30/30 [==============================] - 73s 2s/step - loss: 0.5483 - accuracy: 0.9630 - val_loss: 0.5876 - val_accuracy: 0.9747
# Epoch 3/10
# 30/30 [==============================] - 75s 3s/step - loss: 0.2902 - accuracy: 0.9873 - val_loss: 0.7458 - val_accuracy: 0.9747
# Epoch 4/10
# 30/30 [==============================] - 80s 3s/step - loss: 0.1896 - accuracy: 0.9810 - val_loss: 0.6847 - val_accuracy: 0.9831
# Epoch 1/10
# 30/30 [==============================] - 74s 2s/step - loss: 0.2985 - accuracy: 0.9176 - val_loss: 0.0821 - val_accuracy: 0.9873
# Epoch 2/10
# 30/30 [==============================] - 68s 2s/step - loss: 0.1058 - accuracy: 0.9757 - val_loss: 0.0658 - val_accuracy: 0.9873
# Epoch 3/10
# 30/30 [==============================] - 70s 2s/step - loss: 0.0878 - accuracy: 0.9820 - val_loss: 0.0624 - val_accuracy: 0.9873
# Epoch 4/10
# 30/30 [==============================] - 67s 2s/step - loss: 0.0812 - accuracy: 0.9820 - val_loss: 0.0643 - val_accuracy: 0.9873
# Epoch 5/10
# 30/30 [==============================] - 76s 3s/step - loss: 0.0784 - accuracy: 0.9831 - val_loss: 0.0636 - val_accuracy: 0.9873
# Epoch 1/10
# 15/15 [==============================] - 65s 4s/step - loss: 3.3482 - accuracy: 0.9240 - val_loss: 0.7817 - val_accuracy: 0.9831
# Epoch 2/10
# 15/15 [==============================] - 66s 4s/step - loss: 0.3160 - accuracy: 0.9789 - val_loss: 0.6468 - val_accuracy: 0.9662
# Epoch 3/10
# 15/15 [==============================] - 63s 4s/step - loss: 0.0623 - accuracy: 0.9852 - val_loss: 0.5754 - val_accuracy: 0.9789
# Epoch 4/10
# 15/15 [==============================] - 65s 4s/step - loss: 0.0144 - accuracy: 0.9968 - val_loss: 0.6029 - val_accuracy: 0.9789
# Epoch 5/10
# 15/15 [==============================] - 65s 4s/step - loss: 0.0081 - accuracy: 0.9989 - val_loss: 0.6269 - val_accuracy: 0.9789
# Epoch 1/10
# 15/15 [==============================] - 65s 4s/step - loss: 0.1858 - accuracy: 0.9366 - val_loss: 0.0671 - val_accuracy: 0.9831
# Epoch 2/10
# 15/15 [==============================] - 64s 4s/step - loss: 0.0870 - accuracy: 0.9747 - val_loss: 0.0625 - val_accuracy: 0.9873
# Epoch 3/10
# 15/15 [==============================] - 61s 4s/step - loss: 0.0783 - accuracy: 0.9810 - val_loss: 0.0658 - val_accuracy: 0.9873
# Epoch 4/10
# 15/15 [==============================] - 66s 4s/step - loss: 0.0734 - accuracy: 0.9831 - val_loss: 0.0597 - val_accuracy: 0.9873
# Epoch 5/10
# 15/15 [==============================] - 84s 6s/step - loss: 0.0634 - accuracy: 0.9820 - val_loss: 0.0611 - val_accuracy: 0.9873
# Epoch 6/10
# 15/15 [==============================] - 66s 4s/step - loss: 0.0630 - accuracy: 0.9831 - val_loss: 0.0635 - val_accuracy: 0.9873
# Epoch 1/10
# 15/15 [==============================] - 78s 5s/step - loss: 1.1258 - accuracy: 0.9377 - val_loss: 0.2201 - val_accuracy: 0.9789
# Epoch 2/10
# 15/15 [==============================] - 81s 6s/step - loss: 0.2558 - accuracy: 0.9725 - val_loss: 0.2316 - val_accuracy: 0.9873
# Epoch 3/10
# 15/15 [==============================] - 74s 5s/step - loss: 0.1900 - accuracy: 0.9916 - val_loss: 0.4470 - val_accuracy: 0.9873
# Epoch 1/10
# 15/15 [==============================] - 63s 4s/step - loss: 0.2788 - accuracy: 0.9356 - val_loss: 0.0905 - val_accuracy: 0.9873
# Epoch 2/10
# 15/15 [==============================] - 64s 4s/step - loss: 0.1118 - accuracy: 0.9715 - val_loss: 0.0673 - val_accuracy: 0.9873
# Epoch 3/10
# 15/15 [==============================] - 74s 5s/step - loss: 0.0875 - accuracy: 0.9789 - val_loss: 0.0669 - val_accuracy: 0.9873
# Epoch 4/10
# 15/15 [==============================] - 74s 5s/step - loss: 0.0774 - accuracy: 0.9820 - val_loss: 0.0670 - val_accuracy: 0.9873
# Epoch 5/10
# 15/15 [==============================] - 5272s 376s/step - loss: 0.0723 - accuracy: 0.9831 - val_loss: 0.0679 - val_accuracy: 0.9873
# Epoch 1/10
# 15/15 [==============================] - 59s 4s/step - loss: 3.2444 - accuracy: 0.8976 - val_loss: 0.7027 - val_accuracy: 0.9662
# Epoch 2/10
# 15/15 [==============================] - 7234s 516s/step - loss: 0.2840 - accuracy: 0.9863 - val_loss: 0.5029 - val_accuracy: 0.9831
# Epoch 3/10
# 15/15 [==============================] - 6119s 436s/step - loss: 0.0473 - accuracy: 0.9873 - val_loss: 0.4018 - val_accuracy: 0.9705
# Epoch 4/10
# 15/15 [==============================] - 83s 6s/step - loss: 0.0318 - accuracy: 0.9937 - val_loss: 0.3130 - val_accuracy: 0.9789
# Epoch 5/10
# 15/15 [==============================] - 56s 4s/step - loss: 2.1204e-04 - accuracy: 1.0000 - val_loss: 0.2914 - val_accuracy: 0.9789
# Epoch 6/10
# 15/15 [==============================] - 55s 4s/step - loss: 1.3110e-04 - accuracy: 1.0000 - val_loss: 0.2891 - val_accuracy: 0.9789
# Epoch 7/10
# 15/15 [==============================] - 57s 4s/step - loss: 1.3310e-04 - accuracy: 1.0000 - val_loss: 0.2897 - val_accuracy: 0.9789
# Epoch 8/10
# 15/15 [==============================] - 55s 4s/step - loss: 1.0451e-04 - accuracy: 1.0000 - val_loss: 0.2919 - val_accuracy: 0.9789
# Epoch 1/10
# 15/15 [==============================] - 56s 4s/step - loss: 0.2052 - accuracy: 0.9293 - val_loss: 0.0641 - val_accuracy: 0.9789
# Epoch 2/10
# 15/15 [==============================] - 54s 4s/step - loss: 0.1000 - accuracy: 0.9715 - val_loss: 0.0626 - val_accuracy: 0.9831
# Epoch 3/10
# 15/15 [==============================] - 55s 4s/step - loss: 0.0895 - accuracy: 0.9778 - val_loss: 0.0633 - val_accuracy: 0.9873
# Epoch 4/10
# 15/15 [==============================] - 53s 4s/step - loss: 0.0810 - accuracy: 0.9789 - val_loss: 0.0618 - val_accuracy: 0.9873
# Epoch 5/10
# 15/15 [==============================] - 54s 4s/step - loss: 0.0680 - accuracy: 0.9820 - val_loss: 0.0630 - val_accuracy: 0.9873
# Epoch 6/10
# 15/15 [==============================] - 55s 4s/step - loss: 0.0714 - accuracy: 0.9820 - val_loss: 0.0639 - val_accuracy: 0.9873
# Epoch 1/10
# 15/15 [==============================] - 55s 4s/step - loss: 1.4403 - accuracy: 0.8965 - val_loss: 0.4060 - val_accuracy: 0.9747
# Epoch 2/10
# 15/15 [==============================] - 54s 4s/step - loss: 0.3890 - accuracy: 0.9820 - val_loss: 0.4340 - val_accuracy: 0.9747
# Epoch 3/10
# 15/15 [==============================] - 56s 4s/step - loss: 0.1670 - accuracy: 0.9810 - val_loss: 0.5179 - val_accuracy: 0.9873
# Epoch 1/10
# 15/15 [==============================] - 58s 4s/step - loss: 0.4061 - accuracy: 0.8807 - val_loss: 0.1342 - val_accuracy: 0.9873
# Epoch 2/10
# 15/15 [==============================] - 56s 4s/step - loss: 0.1399 - accuracy: 0.9715 - val_loss: 0.0829 - val_accuracy: 0.9873
# Epoch 3/10
# 15/15 [==============================] - 56s 4s/step - loss: 0.1006 - accuracy: 0.9789 - val_loss: 0.0728 - val_accuracy: 0.9873
# Epoch 4/10
# 15/15 [==============================] - 56s 4s/step - loss: 0.0869 - accuracy: 0.9778 - val_loss: 0.0697 - val_accuracy: 0.9873
# Epoch 5/10
# 15/15 [==============================] - 58s 4s/step - loss: 0.0811 - accuracy: 0.9831 - val_loss: 0.0699 - val_accuracy: 0.9873
# Epoch 6/10
# 15/15 [==============================] - 57s 4s/step - loss: 0.0748 - accuracy: 0.9842 - val_loss: 0.0682 - val_accuracy: 0.9873
# Epoch 7/10
# 15/15 [==============================] - 57s 4s/step - loss: 0.0715 - accuracy: 0.9842 - val_loss: 0.0665 - val_accuracy: 0.9873
# Epoch 8/10
# 15/15 [==============================] - 58s 4s/step - loss: 0.0722 - accuracy: 0.9842 - val_loss: 0.0668 - val_accuracy: 0.9873
# Epoch 9/10
# 15/15 [==============================] - 56s 4s/step - loss: 0.0720 - accuracy: 0.9852 - val_loss: 0.0663 - val_accuracy: 0.9873
# Epoch 10/10
# 15/15 [==============================] - 58s 4s/step - loss: 0.0624 - accuracy: 0.9863 - val_loss: 0.0661 - val_accuracy: 0.9873
# Epoch 1/10
# 8/8 [==============================] - 75s 10s/step - loss: 3.6530 - accuracy: 0.8838 - val_loss: 0.9793 - val_accuracy: 0.9789
# Epoch 2/10
# 8/8 [==============================] - 59s 7s/step - loss: 0.7984 - accuracy: 0.9789 - val_loss: 0.7814 - val_accuracy: 0.9873
# Epoch 3/10
# 8/8 [==============================] - 59s 7s/step - loss: 0.1941 - accuracy: 0.9968 - val_loss: 0.6665 - val_accuracy: 0.9831
# Epoch 4/10
# 8/8 [==============================] - 59s 8s/step - loss: 0.0668 - accuracy: 0.9905 - val_loss: 0.6338 - val_accuracy: 0.9789
# Epoch 5/10
# 8/8 [==============================] - 59s 8s/step - loss: 0.0232 - accuracy: 0.9968 - val_loss: 0.6563 - val_accuracy: 0.9789
# Epoch 6/10
# 8/8 [==============================] - 60s 8s/step - loss: 1.7515e-04 - accuracy: 1.0000 - val_loss: 0.6815 - val_accuracy: 0.9789
# Epoch 1/10
# 8/8 [==============================] - 60s 8s/step - loss: 0.2045 - accuracy: 0.9102 - val_loss: 0.0634 - val_accuracy: 0.9831
# Epoch 2/10
# 8/8 [==============================] - 61s 8s/step - loss: 0.0898 - accuracy: 0.9789 - val_loss: 0.0601 - val_accuracy: 0.9873
# Epoch 3/10
# 8/8 [==============================] - 60s 8s/step - loss: 0.0693 - accuracy: 0.9831 - val_loss: 0.0602 - val_accuracy: 0.9873
# Epoch 4/10
# 8/8 [==============================] - 60s 8s/step - loss: 0.0635 - accuracy: 0.9863 - val_loss: 0.0620 - val_accuracy: 0.9873
# Epoch 1/10
# 8/8 [==============================] - 63s 8s/step - loss: 2.6727 - accuracy: 0.8691 - val_loss: 0.3204 - val_accuracy: 0.9831
# Epoch 2/10
# 8/8 [==============================] - 63s 8s/step - loss: 0.5255 - accuracy: 0.9398 - val_loss: 0.2336 - val_accuracy: 0.9831
# Epoch 3/10
# 8/8 [==============================] - 63s 8s/step - loss: 0.0914 - accuracy: 0.9831 - val_loss: 0.2401 - val_accuracy: 0.9873
# Epoch 4/10
# 8/8 [==============================] - 62s 8s/step - loss: 0.1364 - accuracy: 0.9894 - val_loss: 0.2815 - val_accuracy: 0.9873
# Epoch 1/10
# 8/8 [==============================] - 65s 8s/step - loss: 0.4187 - accuracy: 0.9007 - val_loss: 0.1851 - val_accuracy: 0.9873
# Epoch 2/10
# 8/8 [==============================] - 66s 8s/step - loss: 0.1634 - accuracy: 0.9704 - val_loss: 0.1016 - val_accuracy: 0.9873
# Epoch 3/10
# 8/8 [==============================] - 68s 9s/step - loss: 0.1053 - accuracy: 0.9768 - val_loss: 0.0775 - val_accuracy: 0.9873
# Epoch 4/10
# 8/8 [==============================] - 68s 9s/step - loss: 0.0877 - accuracy: 0.9799 - val_loss: 0.0700 - val_accuracy: 0.9873
# Epoch 5/10
# 8/8 [==============================] - 65s 8s/step - loss: 0.0812 - accuracy: 0.9831 - val_loss: 0.0687 - val_accuracy: 0.9873
# Epoch 6/10
# 8/8 [==============================] - 67s 8s/step - loss: 0.0787 - accuracy: 0.9842 - val_loss: 0.0668 - val_accuracy: 0.9873
# Epoch 7/10
# 8/8 [==============================] - 66s 8s/step - loss: 0.0722 - accuracy: 0.9852 - val_loss: 0.0669 - val_accuracy: 0.9873
# Epoch 8/10
# 8/8 [==============================] - 70s 9s/step - loss: 0.0719 - accuracy: 0.9852 - val_loss: 0.0673 - val_accuracy: 0.9873
# Epoch 1/10
# 8/8 [==============================] - 66s 8s/step - loss: 5.5400 - accuracy: 0.8173 - val_loss: 1.5593 - val_accuracy: 0.9747
# Epoch 2/10
# 8/8 [==============================] - 68s 9s/step - loss: 2.0389 - accuracy: 0.9704 - val_loss: 0.9844 - val_accuracy: 0.9789
# Epoch 3/10
# 8/8 [==============================] - 68s 9s/step - loss: 0.4528 - accuracy: 0.9799 - val_loss: 0.7745 - val_accuracy: 0.9747
# Epoch 4/10
# 8/8 [==============================] - 67s 9s/step - loss: 0.1565 - accuracy: 0.9842 - val_loss: 0.5859 - val_accuracy: 0.9831
# Epoch 5/10
# 8/8 [==============================] - 68s 9s/step - loss: 0.0219 - accuracy: 0.9958 - val_loss: 0.4935 - val_accuracy: 0.9831
# Epoch 6/10
# 8/8 [==============================] - 70s 9s/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.4628 - val_accuracy: 0.9873
# Epoch 7/10
# 8/8 [==============================] - 68s 9s/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 0.4561 - val_accuracy: 0.9873
# Epoch 8/10
# 8/8 [==============================] - 67s 9s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.4557 - val_accuracy: 0.9873
# Epoch 9/10
# 8/8 [==============================] - 71s 9s/step - loss: 0.0042 - accuracy: 0.9979 - val_loss: 0.4587 - val_accuracy: 0.9873
# Epoch 10/10
# 8/8 [==============================] - 68s 9s/step - loss: 0.0026 - accuracy: 0.9989 - val_loss: 0.4615 - val_accuracy: 0.9873
# Epoch 1/10
# 8/8 [==============================] - 79s 10s/step - loss: 0.2257 - accuracy: 0.9081 - val_loss: 0.0593 - val_accuracy: 0.9831
# Epoch 2/10
# 2/8 [======>.......................] - ETA: 51s - loss: 0.0718 - accuracy: 0.9883
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/ps/310fvxcx6y55_xvdkg77780h0000gn/T/ipykernel_87388/3528408337.py in <module>
#      49
#      50                         # Train the model and save the validation accuracy and history
# ---> 51                         history = model.fit(X_train, y_train, class_weight=class_weights, epochs=10, batch_size=bs, validation_data=(X_test, y_test), callbacks=[early_stopping])
#      52                         val_accuracy = history.history['val_accuracy'][-1]
#      53
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1648                         ):
#    1649                             callbacks.on_train_batch_begin(step)
# -> 1650                             tmp_logs = self.train_function(iterator)
#    1651                             if data_handler.should_sync:
#    1652                                 context.async_wait()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     878
#     879       with OptionalXlaContext(self._jit_compile):
# --> 880         result = self._call(*args, **kwds)
#     881
#     882       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     910       # In this case we have created variables on the first call, so we run the
#     911       # defunned version which is guaranteed to never create variables.
# --> 912       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913     elif self._variable_creation_fn is not None:
#     914       # Release the lock early so that multiple threads can perform the call
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     132       (concrete_function,
#     133        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134     return concrete_function._call_flat(
#     135         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     136
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     376       with _InterpolateFunctionError(self):
#     377         if cancellation_manager is None:
# --> 378           outputs = execute.execute(
#     379               str(self.signature.name),
#     380               num_outputs=self._num_outputs,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
#results_df.to_csv('model_compare.csv')

# %%
results_df2 = results_df[results_df['batch_size']<=64].iloc[:,2:-1]
results_df2.columns
# Out:
# Index(['batch_size', 'dropout_rate', 'num_hidden_layers',
#        'activation_function', 'val_accuracy'],
#       dtype='object')

# %%
# Use pivot_table() to reshape the table
pivoted_df = results_df2.pivot_table(values='val_accuracy', index=['batch_size', 'dropout_rate', 'num_hidden_layers', 'activation_function'], columns='val_accuracy')

# Reset the index to make all the columns visible
pivoted_df = pivoted_df.reset_index()

# Rename the columns to remove the "value" prefix
pivoted_df = pivoted_df.rename(columns={'val_accuracy': 'accuracy'})
pivoted_df
# Out:
# val_accuracy  batch_size  dropout_rate  num_hidden_layers activation_function
# 0                     32           0.1                  1                relu
# 1                     32           0.1                  1             sigmoid
# 2                     32           0.1                  2                relu
# 3                     32           0.1                  2             sigmoid
# 4                     32           0.2                  1                relu
# 5                     32           0.2                  1             sigmoid
# 6                     32           0.2                  2                relu
# 7                     32           0.2                  2             sigmoid
# 8                     64           0.1                  1                relu
# 9                     64           0.1                  1             sigmoid
# 10                    64           0.1                  2                relu
# 11                    64           0.1                  2             sigmoid
# 12                    64           0.2                  1                relu
# 13                    64           0.2                  1             sigmoid
# 14                    64           0.2                  2                relu
# 15                    64           0.2                  2             sigmoid

# %%
# Convert the dataframe to a long table using pd.melt()
id_vars = ['batch_size', 'dropout_rate', 'num_hidden_layers',
       'activation_function']
value_vars = ['val_accuracy']
df_long = pd.melt(results_df2, id_vars=id_vars, value_vars=value_vars, var_name='metric', value_name='value')
df_long
# Out:
#    batch_size dropout_rate num_hidden_layers activation_function
# 0          32          0.1                 1                relu  \
# 1          32          0.1                 1             sigmoid
# 2          32          0.1                 2                relu
# 3          32          0.1                 2             sigmoid
# 4          32          0.2                 1                relu
# 5          32          0.2                 1             sigmoid
# 6          32          0.2                 2                relu
# 7          32          0.2                 2             sigmoid
# 8          64          0.1                 1                relu
# 9          64          0.1                 1             sigmoid
# 10         64          0.1                 2                relu
# 11         64          0.1                 2             sigmoid
# 12         64          0.2                 1                relu
# 13         64          0.2                 1             sigmoid
# 14         64          0.2                 2                relu
# 15         64          0.2                 2             sigmoid
#
#           metric     value
# 0   val_accuracy  0.978903
# 1   val_accuracy  0.983122
# 2   val_accuracy  0.978903
# 3   val_accuracy  0.987342
# 4   val_accuracy  0.970464
# 5   val_accuracy  0.978903
# 6   val_accuracy  0.983122
# 7   val_accuracy  0.987342
# 8   val_accuracy  0.978903
# 9   val_accuracy  0.987342
# 10  val_accuracy  0.987342
# 11  val_accuracy  0.987342
# 12  val_accuracy  0.978903
# 13  val_accuracy  0.987342
# 14  val_accuracy  0.987342
# 15  val_accuracy  0.987342

# %%
results_df3 = results_df[results_df['batch_size']<=64]#.iloc[:,2:]
results_df3.columns
# Out:
# Index(['learning_rate', 'optimizer', 'batch_size', 'dropout_rate',
#        'num_hidden_layers', 'activation_function', 'val_accuracy', 'history'],
#       dtype='object')

# %%
fig, ax = plt.subplots()

for index, row in results_df3.iterrows():
    ax.plot(row['history'].history['loss'], label=f"{row['optimizer']} {row['learning_rate']} {row['batch_size']} {row['dropout_rate']} {row['num_hidden_layers']} {row['activation_function']}")

# create a legend object
legend = ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %%
#results_df.to_csv('model_compare.csv')

# %%
model_predictions_test=model.predict(X_test)
threshold = 0.99999 # play around this threshold

predicted_labels_test = (model_predictions_test > threshold).astype(int)

accuracy = accuracy_score(y_test, predicted_labels_test)
print(accuracy)
# Out:
# 8/8 [==============================] - 12s 2s/step
# 0.9113924050632911

# %%
sum(predicted_labels_test)
# Out:
# array([142])

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, predicted_labels_test)

# Plot heatmap
sns.heatmap(cm, annot=True, cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()

# %%
convert_label_dict={1: 'food', 0: 'exterior'}

# %%
#find misclassified images
def find_mismatch_pos(list1, list2):
    all_pos=[]
    for i in range(len(list1)):
        if list1[i] != list2[i]:
            all_pos.append(i)
    return all_pos # if no mismatch found

misclassified = find_mismatch_pos(y_test, predicted_labels_test)

# %%
for ind, item in enumerate(misclassified):
    predict_label=predicted_labels_test[item][0]
    actual_label=y_test[item]
    print('image ' + str(ind) + ' actual label:' + (convert_label_dict[actual_label]))
    print('image ' + str(ind) + ' predict label:' + (convert_label_dict[predict_label]))
    plt.imshow(new_test[item], cmap='gray')
    plt.show()
    
# image 4 has a wrong label

# %%
 # show images in order to check prediction 
for ind, item in enumerate(X_test):
    label=predicted_labels_test[ind][0]
    print('image ' + str(ind) + ' label:' + (convert_label_dict[label]))
    plt.imshow(item, cmap='gray')
    plt.show()

# %%
def save_image(filename):
    p = PdfPages(filename)
    for ind, item in enumerate(new_images): # show images in order to check prediction 
        label=predicted_labels[ind][0]
        fig= plt.figure()
        plt.imshow(item, cmap='gray')
        plt.title('image ' + str(ind) + ' label:' + (convert_label_dict[label]))
        fig.savefig(p, format='pdf') 
    # close the object
    p.close()  
    
# name Pdf file
#filename = "multi_plot_image2.pdf"  
#save_image(filename)

# %% [markdown]
# # Load saved food vs exterior model

# %%
import os
os.getcwd()

# %%
from keras.models import load_model

# %%
import tensorflow as tf

# %%
#new_model = tf.keras.models.load_model('food_interior_classifier.h5')

# %%
# Predict new images with the model
model_predictions=model.predict(test)

# %%
plt.hist(model_predictions) # probabilities are at two extreme

# %%
# set the threshold
threshold = 0.5 # adjust this threshold to make sure what we predict as food is really food

# convert predicted probabilities to labels 0 and 1
predicted_labels = (model_predictions > threshold).astype(int)
# print the predicted labels

# %%
test.shape

# %%
sum(predicted_labels)

# %%
label_dict={1: 'food', 0: 'exterior'}
predicted=[]

food_only=[]
cuisine_labels=[]
image_name=[]
for ind, item in enumerate(test): # show images in order to check prediction 
    label=predicted_labels[ind][0]
    predicted.append(label)
    if label==1:
        food_only.append(item)
        cuisine_labels.append(test_labels[ind])
        image_name.append(test_image_names[ind])
    #print('image ' + str(ind) + ' label:' + (label_dict[label]))
    #plt.imshow(item, cmap='gray')
    #plt.show()

# %%
len(test)

# %%
with open('food_only.txt', 'w') as f:
    for item in image_name:
        f.write("%s\n" % item)

# %%
len(food_only)

# %%
# double check labels
#for test_id in range(10):
#    plt.imshow(food_only[test_id], cmap='gray')
#    plt.title(cuisine_labels[test_id])
#    plt.show()

round(sum(predicted)/len(predicted),2)
# percent predicted as food images

# %%
def save_image(filename, food_only):
    p = PdfPages(filename)
    for ind, item in enumerate(food_only): # show images in order to check prediction 
        #label=predicted_labels[ind][0]
        fig= plt.figure()
        plt.imshow(item, cmap='gray')
        plt.title('image ' + str(image_name[ind]))
        fig.savefig(p, format='pdf') 
    # close the object
    p.close()
#filename = "cuisine_food_predicted2.pdf"  
#save_image(filename, food_only)

# %%
#test_image_names, this contains the labels of the test image

# %% [markdown]
# # Check about the interior

# %%
#wrong =['2643058', '778212', '297614', '5414007', '5142831', '2026022', '1250600', '1004760', '2241860', '1198837', '1943514']

# %%
# indices = [i for i, x in enumerate(image_name) if x in wrong]
# indices

# %%
# cuisine_labels_filtered = [cuisine_labels[i] for i in range(len(cuisine_labels)) if i not in indices]

# %%
# food_only_filtered = [food_only[i] for i in range(len(food_only)) if i not in indices]

# %% [markdown]
# # Modelling after filtering out non-food

# %%
import keras

# %%
final_labels= cuisine_labels.copy()

# %%
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
# Encode labels in column 'species'.
final_labels_int= label_encoder.fit_transform(final_labels)

# %%
class_cat=pd.DataFrame(final_labels)
class_cat.columns=['label']
dummies = pd.get_dummies(class_cat)
dummies.shape

# %%
set(final_labels)

# %%
class_cat.reset_index().groupby('label').count()

# %%
X = np.array(food_only)
y= np.array(dummies)

# %%
import functools
#https://stackoverflow.com/questions/51951358/keras-how-to-get-top-k-accuracy
#top3_acc = functools.partial(keras.metrics.top_k_categorical_accuracy, k=3)
#top3_acc.__name__ = 'top3_acc'

#original_labels = np.argmax(y, axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify= final_labels_int, test_size=0.2, random_state=42)

# %%
# class_weights2 = compute_class_weight(
#                                         class_weight = "balanced",
#                                         classes = np.unique(final_labels_int),
#                                         y = final_labels_int                                                    
#                                     )
# class_weights2 = dict(zip(np.unique(final_labels_int), class_weights))
# class_weights2

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.applications import VGG16

from tensorflow.keras.layers import Dropout


# Load the pre-trained model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

# Freeze pre-trained layers (compare with no freezing)
for layer in base_model.layers:
    layer.trainable = False

early_stopping = EarlyStopping(monitor='val_loss', patience=4)

    
# Define your own classification layers
model_cusine = Sequential()
model_cusine.add(base_model)
model_cusine.add(Dropout(0.2)) # avoid overfitting
model_cusine.add(Flatten())


#model.add(Dense(128, activation='relu'))

#val acc>0.2
model_cusine.add(Dense(64, activation='relu'))
#model.add(Dropout(0.2)) # adding it twuice to avoid overfitting
model_cusine.add(Dense(64, activation='relu'))
#model.add(Dropout(0.2)) # adding it twuice to avoid overfitting

model_cusine.add(Dense(7, activation='softmax'))
#https://datascience.stackexchange.com/questions/39264/how-does-sigmoid-activation-work-in-multi-class-classification-problems

# Compile the model
model_cusine.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy','top_k_categorical_accuracy'])
              #,top3_acc]) #sparse_categorical_crossentropy

# %%
model_cusine.summary()

# %%
original_labels_y_train = np.argmax(y_train, axis=1)


# from sklearn.utils import class_weight
# class_weights = compute_class_weight(class_weight = "balanced",
#                                          classes = np.unique(original_labels_y_train),
#                                          y = original_labels_y_train                                                    
#                                      )
# class_weights = dict(zip(np.unique(original_labels_y_train), class_weights))

# %%
class_weights

# %%
# Train the model
history2=model_cusine.fit(X_train, y_train, #class_weight=class_weights, 
                          epochs=10, batch_size=16, 
                          validation_data=(X_test, y_test), callbacks=[early_stopping])


# Evaluate the model on test set
#score = model_cusine.evaluate(X_test, y_test)
#print('Test accuracy:', score[1])

# %%
# plot loss curve
plt.plot(history2.history['loss'], label='training loss')
plt.plot(history2.history['val_loss'], label='validation loss')
plt.legend()
plt.show()

# %%
y_pred_prob = model_cusine.predict(X)
y_pred = [int(np.argmax(i) )for i in y_pred_prob]

# %%
#y_pred_prob = model_cusine.predict(X_test)
#y_pred = [int(np.argmax(i) )for i in y_pred_prob]

# %%
original_labels = np.argmax(y, axis=1)
original_labels

# %%
y[1]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools

# Define your actual class names as a list
class_names = ['Chinese',
 'French',
 'Indian',
 'Italian',
 'Japanese',
 'Modern British',
 'Thai']

# Generate some example data for demonstration purposes
# Including both training and test
y_pred = y_pred
y_true = original_labels

# Calculate the confusion matrix
cm = confusion_matrix(y_true, y_pred)

# %%
# Define a function to plot the confusion matrix
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function plots the confusion matrix.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# Plot the confusion matrix
plt.figure()
plot_confusion_matrix(cm, classes=class_names, title='Confusion matrix')
plt.show()

# %%
# to do

# %%
# Manually go through the food images, anyone exterior image there?

# %%
# Now either consider class weight, or make them more balanced manually

# %%
# Try different losses, sparse_categorical vs categorical, try using y as label encoded vs dummy encoded

# %%
# Look at some misclassified images

# %%
# Add explanation technique
