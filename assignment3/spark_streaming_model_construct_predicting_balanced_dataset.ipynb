# %%
import threading

# Helper thread to avoid the Spark StreamingContext from blocking Jupyter
        
class StreamingThread(threading.Thread):
    def __init__(self, ssc):

        super().__init__()
        self.ssc = ssc
    def run(self):
        self.ssc.start()
        self.ssc.awaitTermination()
    def stop(self):
        print('----- Stopping... this may take a few seconds -----')
        self.ssc.stop(stopSparkContext=False, stopGraceFully=True)

# %%
sc
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.0.171:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# # build model

# %%
from pyspark.streaming import StreamingContext
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.ml.feature import Tokenizer, StopWordsRemover, CountVectorizer, IDF, StringIndexer, HashingTF
from pyspark.ml.classification import LogisticRegression, RandomForestClassifier
from pyspark.ml import Pipeline
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.sql.functions import expr
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.ml.feature import Word2Vec
from pyspark.ml import Pipeline
from pyspark.sql.functions import split, rand
from pyspark.sql.types import StructType, StructField, StringType, DoubleType

file_location="reviews.csv"

# %%
# create a SparkSession 
spark = SparkSession.builder \
    .appName("assignment 3") \
    .config("spark.driver.memory", "2g") \
    .config("spark.executor.memory", "2g") \
    .config("spark.driver.cores", "2") \
    .getOrCreate()

# %%
# read csv

text_df = spark.read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .option("multiline", "true") \
    .option("delimiter", "\t") \
    .csv(file_location)

text_df = text_df.select(col('review_text'), col('label'))
text_df.show()
# Out:
# +--------------------+-----+
# |         review_text|label|
# +--------------------+-----+
# |i can confirm tha...|  1.0|
# |Really good game,...|  1.0|
# |Its not finished ...|  1.0|
# |Hey. It's really ...|  1.0|
# |          Fun so far|  1.0|
# |I'd rather play W...|  0.0|
# |I have been playi...|  1.0|
# |Nice game! Loads ...|  1.0|
# |All hail NA serve...|  1.0|
# |enjoying it so fa...|  1.0|
# |This game came as...|  1.0|
# |         Great fun  |  1.0|
# |Fantastic consept...|  1.0|
# |You know the game...|  1.0|
# |EDIT: My issues h...|  1.0|
# |AMAZIIIIIIIIIIING...|  1.0|
# |In its current st...|  0.0|
# |Играю в Калибр го...|  1.0|
# |Secret Word: Prou...|  1.0|
# |Fated Word: Death...|  1.0|
# +--------------------+-----+
# only showing top 20 rows

# %%
# Remove duplicate rows
text_df = text_df.dropDuplicates()
# Remove rows with missing values
text_df = text_df.na.drop()

# %%
text_df.select("label").distinct().show()
# Out:
# +--------------------+
# |               label|
# +--------------------+
# |                 1.0|
# |                 0.0|
# |It's been at leas...|
# |[td]✔️ Exciting p...|
# |- I literally onl...|
# +--------------------+

# %%
# Remove rows with unexpected labels
text_df = text_df.filter((col("label") == 1.0) | (col("label") == 0.0))
print("Number of rows after filtering: ", text_df.count())
print("Number of rows after filtering with 1 labelled: ", text_df.filter(col("label") == 1.0).count())
print("Number of rows after filtering with 0 labelled: ", text_df.filter(col("label") == 0.0).count())
# Out:
# Number of rows after filtering:  36913
# Number of rows after filtering with 1 labelled:  29406
# Number of rows after filtering with 0 labelled:  7507

# %%
# make balanced dataset
text_df_0 = text_df.filter(col("label") == 0.0)  
text_df_1 = text_df.filter(col("label") == 1.0) 
sampled_text_df_1 = text_df_1.orderBy(rand()).limit(text_df_0.count())
balance_text_df = text_df_0.union(sampled_text_df_1)
print("1 labelled: ", balance_text_df.filter(col("label") == 1.0).count())
print("0 labelled: ", balance_text_df.filter(col("label") == 0.0).count())
# Out:
# 1 labelled:  7507
# 0 labelled:  7507

# %%
# Split data set
train_data, test_data = balance_text_df.randomSplit([0.8, 0.2], seed=7)
# Out:
# 3012

# %%
# preprocess the data
tokenizer = Tokenizer(inputCol="review_text", outputCol="words")
stopwords_remover = StopWordsRemover(inputCol="words", outputCol="filtered_words", locale="en_US")
count_vectorizer = CountVectorizer(inputCol="filtered_words", outputCol="raw_features")
idf = IDF(inputCol="raw_features", outputCol="features")
string_indexer = StringIndexer(inputCol="label", outputCol="label_index")

# create model
lr = LogisticRegression(featuresCol="features", labelCol="label_index")

# %%
# define params grid
param_grid = ParamGridBuilder() \
   .addGrid(count_vectorizer.vocabSize, [1000, 5000]) \
   .addGrid(lr.regParam, [0.01, 0.1]) \
   .addGrid(lr.elasticNetParam, [0.0, 0.5, 1.0]) \
   .build()

# define the evaluator
evaluator = MulticlassClassificationEvaluator(labelCol="label_index", predictionCol="prediction")

# %%
# create pipeline
pipeline = Pipeline(stages=[tokenizer, stopwords_remover, count_vectorizer, idf, string_indexer, lr])

# define the cross-validator
cv = CrossValidator(estimator=pipeline, estimatorParamMaps=param_grid, evaluator=evaluator, numFolds=3)

# fit pipeline to the training data
cv_model = cv.fit(train_data)

# make predictions on the test data
predictions = cv_model.transform(test_data)

# %%
evaluator = MulticlassClassificationEvaluator(labelCol="label_index", predictionCol="prediction")

# Calculate accuracy
accuracy = evaluator.evaluate(predictions, {evaluator.metricName: "accuracy"})

# Calculate F1 score
f1_score = evaluator.evaluate(predictions, {evaluator.metricName: "f1"})

# Calculate recall
recall = evaluator.evaluate(predictions, {evaluator.metricName: "weightedRecall"})

# Calculate precision
precision = evaluator.evaluate(predictions, {evaluator.metricName: "weightedPrecision"})

print("Accuracy: {:.4f}".format(accuracy))
print("F1 score: {:.4f}".format(f1_score))
print("Recall: {:.4f}".format(recall))
print("Precision: {:.4f}".format(precision))
# Out:
# Accuracy: 0.8234
# F1 score: 0.8227
# Recall: 0.8234
# Precision: 0.8303

# %%
from pyspark.mllib.evaluation import MulticlassMetrics

# Convert the predictions and labels to an RDD
predictionAndLabels = predictions.select("prediction", "label_index").rdd.map(lambda r: (r[0], r[1]))

# Instantiate a MulticlassMetrics object
metrics = MulticlassMetrics(predictionAndLabels)

# Get the confusion matrix as a NumPy array
confusion_matrix = metrics.confusionMatrix().toArray()

# Print the confusion matrix
print("Confusion matrix:")
print(confusion_matrix)
# Out:
# C:\spark\spark-3.3.2-bin-hadoop2\python\pyspark\sql\context.py:157: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# Confusion matrix:
# [[1324.  160.]
#  [ 372. 1156.]]

# %%
# Get the best model from the cross-validation process
best_model = cv_model.bestModel

# Save the my_model
best_model.save("my_logistic_regression2")

# %%
from pyspark.ml import PipelineModel
globals()['models_loaded'] = False
globals()['my_model'] = None

global results
results = []

def process(time, rdd):
    if rdd.isEmpty():
        return
    
    print("========= %s =========" % str(time))
    
    # Convert to data frame
    df = spark.read.json(rdd)
    df = df.withColumn("label", col("label").cast("float"))
    df.show()
    
    # Load in the model if not yet loaded:
    if not globals()['models_loaded']:
        # load in your models here
        globals()['my_model'] = PipelineModel.load('my_logistic_regression2')
        globals()['models_loaded'] = True
        
    # And then predict using the loaded model (uncomment below):
    
    df_result = globals()['my_model'].transform(df)
    df_result.select('label', 'review_text', 'prediction','probability', 'label_index').show()
    
    collected_results = df_result.select('prediction', 'label_index').collect()
    results.extend(collected_results)
    
    # If we have collected 10 results, show the data and clear the results list
    display_results(results)


def display_results(results):
    result_df = spark.createDataFrame(results)
    predictionAndLabels = result_df.select("prediction", "label_index").rdd.map(lambda r: (r[0], r[1]))
    metrics = MulticlassMetrics(predictionAndLabels)
    confusion_matrix = metrics.confusionMatrix().toArray()
    print("Confusion matrix:")
    print(confusion_matrix)

# %%
ssc = StreamingContext(sc, 10)

# %%
lines = ssc.socketTextStream("seppe.net", 7778)
lines.foreachRDD(process)

# %%
ssc_t = StreamingThread(ssc)
ssc_t.start()
# Out:
# ========= 2023-05-24 08:23:10 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# | 605740|  1.0|138882971|                GOod|
# |1928090|  0.0|138882691|For now, I don't ...|
# | 824600|  1.0|138883414|amazing game. It'...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|                GOod|       0.0|[0.63362784686620...|        0.0|
# |  0.0|For now, I don't ...|       1.0|[0.05068748730527...|        1.0|
# |  1.0|amazing game. It'...|       0.0|[0.70612767136726...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[2. 0.]
#  [0. 1.]]
# ========= 2023-05-24 08:23:20 =========
# +------+-----+---------+--------------------+
# |app_id|label|review_id|         review_text|
# +------+-----+---------+--------------------+
# |705040|  0.0|138883411|To say that I'm g...|
# |705040|  0.0|138882712|I'm what you migh...|
# |705040|  0.0|138882151|The sensitivity i...|
# +------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  0.0|To say that I'm g...|       1.0|[0.00464086681327...|        1.0|
# |  0.0|I'm what you migh...|       1.0|[0.32883216931654...|        1.0|
# |  0.0|The sensitivity i...|       1.0|[0.28512823798446...|        1.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[2. 0.]
#  [0. 4.]]
# ========= 2023-05-24 08:23:30 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1268750|  1.0|138884517|Mobile infantry m...|
# |1268750|  1.0|138884446|Been dreaming for...|
# |1268750|  1.0|138884442|  I'm doing my part!|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|Mobile infantry m...|       0.0|[0.74223956237210...|        0.0|
# |  1.0|Been dreaming for...|       0.0|[0.81327573583377...|        0.0|
# |  1.0|  I'm doing my part!|       0.0|[0.81438427542711...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[5. 0.]
#  [0. 4.]]
# ========= 2023-05-24 08:23:40 =========
# +-------+-----+---------+-----------------+
# | app_id|label|review_id|      review_text|
# +-------+-----+---------+-----------------+
# |1268750|  1.0|138884404|i'm Doing my Part|
# +-------+-----+---------+-----------------+
#
# +-----+-----------------+----------+--------------------+-----------+
# |label|      review_text|prediction|         probability|label_index|
# +-----+-----------------+----------+--------------------+-----------+
# |  1.0|i'm Doing my Part|       0.0|[0.55878226957536...|        0.0|
# +-----+-----------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[6. 0.]
#  [0. 4.]]
# ========= 2023-05-24 08:23:50 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1895820|  0.0|138882387|Really great mark...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  0.0|Really great mark...|       1.0|[0.21500024635946...|        1.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[6. 0.]
#  [0. 5.]]
# ========= 2023-05-24 08:24:00 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1783280|  1.0|138882498|Good:\nIncredible...|
# |1934780|  1.0|138884118|still has some wa...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|Good:\nIncredible...|       0.0|[0.65589946482825...|        0.0|
# |  1.0|still has some wa...|       0.0|[0.69823311942971...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[8. 0.]
#  [0. 5.]]
# ========= 2023-05-24 08:24:10 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1934780|  0.0|138883753|Game is literally...|
# |1934780|  1.0|138883115|its jus really fu...|
# |1934780|  1.0|138882980| i like the graph...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  0.0|Game is literally...|       0.0|[0.51831480748811...|        1.0|
# |  1.0|its jus really fu...|       0.0|[0.58406796262463...|        0.0|
# |  1.0| i like the graph...|       0.0|[0.54355242054737...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[10.  0.]
#  [ 1.  5.]]
# ========= 2023-05-24 08:24:20 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1934780|  0.0|138882762|REMOVE ABANDON PE...|
# |1304930|  1.0|138884573|             A+ game|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  0.0|REMOVE ABANDON PE...|       1.0|[0.16825040941397...|        1.0|
# |  1.0|             A+ game|       0.0|[0.57450609940160...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[11.  0.]
#  [ 1.  6.]]
# ========= 2023-05-24 08:24:30 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1304930|  1.0|138884568|Super fun both so...|
# |1304930|  1.0|138884522|     I'm daimond 1\n|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|Super fun both so...|       0.0|[0.63646396449545...|        0.0|
# |  1.0|     I'm daimond 1\n|       0.0|[0.56136699465384...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[13.  0.]
#  [ 1.  6.]]
# ========= 2023-05-24 08:24:40 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1465560|  0.0|138883870|Gender politics g...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  0.0|Gender politics g...|       1.0|[0.47431032295532...|        1.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[13.  0.]
#  [ 1.  7.]]
# ========= 2023-05-24 08:24:50 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |2417620|  1.0|138883267|A short and sweet...|
# |2344630|  1.0|138883410|               10/10|
# |1062810|  1.0|138884761|                   p|
# |1062810|  0.0|138884199|I've tried 3 runs...|
# |1062810|  0.0|138884117|I think this game...|
# +-------+-----+---------+--------------------+
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|A short and sweet...|       0.0|[0.78246162934709...|        0.0|
# |  1.0|               10/10|       0.0|[0.78905650341143...|        0.0|
# |  1.0|                   p|       0.0|[0.57940247423050...|        0.0|
# |  0.0|I've tried 3 runs...|       1.0|[0.14929982587313...|        1.0|
# |  0.0|I think this game...|       1.0|[0.05165264794829...|        1.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[16.  0.]
#  [ 1.  9.]]
# ========= 2023-05-24 08:25:00 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1062810|  1.0|138883590|      unique and fun|
# |1062810|  1.0|138882916|This is a fantast...|
# |1062810|  1.0|138882797|Gameplay loop is ...|
# |1744610|  1.0|138883053|good game, creati...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|      unique and fun|       0.0|[0.6428468236581,...|        0.0|
# |  1.0|This is a fantast...|       0.0|[0.95464324552465...|        0.0|
# |  1.0|Gameplay loop is ...|       0.0|[0.81927689491403...|        0.0|
# |  1.0|good game, creati...|       0.0|[0.67493222917700...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[20.  0.]
#  [ 1.  9.]]
# ========= 2023-05-24 08:25:30 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1616110|  1.0|138882893|simply put...this...|
# |1590160|  1.0|138883151|I think it's got ...|
# |2141910|  1.0|138884871|This game is awes...|
# |2141910|  0.0|138884181|So, i've played t...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|simply put...this...|       0.0|[0.89359767158541...|        0.0|
# |  1.0|I think it's got ...|       0.0|[0.97556521482809...|        0.0|
# |  1.0|This game is awes...|       0.0|[0.98891516164583...|        0.0|
# |  0.0|So, i've played t...|       1.0|[0.39962349061689...|        1.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[23.  0.]
#  [ 1. 10.]]
# ========= 2023-05-24 08:25:40 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |2141910|  1.0|138884150|Do you like Magic...|
# |2141910|  1.0|138883561|Its the best CCG ...|
# |2141910|  0.0|138883499|Still the same po...|
# |2141910|  1.0|138883448|                  ya|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|Do you like Magic...|       0.0|[0.70998761852997...|        0.0|
# |  1.0|Its the best CCG ...|       0.0|[0.90529688242980...|        0.0|
# |  0.0|Still the same po...|       1.0|[0.30862598087184...|        1.0|
# |  1.0|                  ya|       0.0|[0.55195046233787...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[26.  0.]
#  [ 1. 11.]]
# ========= 2023-05-24 08:25:50 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |2141910|  0.0|138883331|Be not deceived: ...|
# |2141910|  1.0|138883203|Same magic arena ...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  0.0|Be not deceived: ...|       1.0|[0.01014895073705...|        1.0|
# |  1.0|Same magic arena ...|       0.0|[0.68324900023725...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[27.  0.]
#  [ 1. 12.]]
# ========= 2023-05-24 08:26:20 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1608230|  1.0|138884714|Great Get for the...|
# |1608230|  1.0|138884287|This game is beau...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|Great Get for the...|       0.0|[0.66066233884800...|        0.0|
# |  1.0|This game is beau...|       0.0|[0.77859496696428...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[29.  0.]
#  [ 1. 12.]]
# ========= 2023-05-24 08:26:30 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1608230|  1.0|138884010|First 20 minutes ...|
# |1608230|  1.0|138883519|Beautiful Game wi...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|First 20 minutes ...|       0.0|[0.67876042762797...|        0.0|
# |  1.0|Beautiful Game wi...|       0.0|[0.99253602466658...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[31.  0.]
#  [ 1. 12.]]
# ========= 2023-05-24 08:26:40 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1649010|  0.0|138883963|Honestly, the fac...|
# |1649010|  1.0|138883109|             \nLike.|
# |1607680|  1.0|138884780|patience simulato...|
# |1276800|  1.0|138883005|Pretty good game ...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  0.0|Honestly, the fac...|       1.0|[0.41238770178827...|        1.0|
# |  1.0|             \nLike.|       0.0|[0.66205511321693...|        0.0|
# |  1.0|patience simulato...|       0.0|[0.72851428084329...|        0.0|
# |  1.0|Pretty good game ...|       0.0|[0.88403221491342...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[34.  0.]
#  [ 1. 13.]]
# ========= 2023-05-24 08:26:50 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1276800|  1.0|138882880|A Platformer RPG ...|
# |2005010|  1.0|138884921|           very nice|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|A Platformer RPG ...|       0.0|[0.96737758642901...|        0.0|
# |  1.0|           very nice|       0.0|[0.66093376610720...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[36.  0.]
#  [ 1. 13.]]
# ========= 2023-05-24 08:27:10 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |2005010|  1.0|138883915|Amazing. One of t...|
# |2005010|  1.0|138883904|The first level o...|
# +-------+-----+---------+--------------------+
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|Amazing. One of t...|       0.0|[0.91364494735496...|        0.0|
# |  1.0|The first level o...|       0.0|[0.50113669327129...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[38.  0.]
#  [ 1. 13.]]
# ========= 2023-05-24 08:27:20 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |2005010|  1.0|138883888|The retro styled ...|
# |2005010|  1.0|138883885|SUFFER NOT THE HE...|
# |2005010|  1.0|138883866|             Pew Pew|
# |2005010|  1.0|138883854|First you get the...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|The retro styled ...|       0.0|[0.57306938131722...|        0.0|
# |  1.0|SUFFER NOT THE HE...|       0.0|[0.63227010281892...|        0.0|
# |  1.0|             Pew Pew|       0.0|[0.57940247423050...|        0.0|
# |  1.0|First you get the...|       0.0|[0.58196949435132...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[42.  0.]
#  [ 1. 13.]]
# ========= 2023-05-24 08:27:30 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |2005010|  1.0|138883830|       spice marine!|
# |2005010|  1.0|138883824|We shall be unsti...|
# |2005010|  1.0|138883798|     20$ Well spent!|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|       spice marine!|       0.0|[0.70456893610100...|        0.0|
# |  1.0|We shall be unsti...|       0.0|[0.59320379684603...|        0.0|
# |  1.0|     20$ Well spent!|       0.0|[0.62834779128838...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[45.  0.]
#  [ 1. 13.]]
# ========= 2023-05-24 08:27:40 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |2005010|  1.0|138883767|games good, has s...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|games good, has s...|       0.0|[0.63686026361102...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[46.  0.]
#  [ 1. 13.]]
# ========= 2023-05-24 08:27:50 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |2154650|  1.0|138884221|ign is too afraid...|
# |2154650|  1.0|138882929|for a 5$ time was...|
# |2424450|  1.0|138884373|AHHH YES THE CIRC...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|ign is too afraid...|       0.0|[0.66769659370733...|        0.0|
# |  1.0|for a 5$ time was...|       1.0|[0.41948953859992...|        0.0|
# |  1.0|AHHH YES THE CIRC...|       0.0|[0.88355375119570...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[48.  1.]
#  [ 1. 13.]]
# ========= 2023-05-24 08:28:00 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1940340|  1.0|138885655|holy fuck this ga...|
# |1940340|  1.0|138885243|every hour of thi...|
# |1940340|  1.0|138885136|A very cautious y...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|holy fuck this ga...|       0.0|[0.58055360208666...|        0.0|
# |  1.0|every hour of thi...|       0.0|[0.66455146223167...|        0.0|
# |  1.0|A very cautious y...|       1.0|[0.47372526041021...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[50.  2.]
#  [ 1. 13.]]
# ========= 2023-05-24 08:28:10 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1940340|  0.0|138883960|The game's RNG is...|
# |1940340|  1.0|138883365|I didn't play Dar...|
# |1159690|  1.0|138884142|its a good game i...|
# |2369390|  1.0|138885711|                guud|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  0.0|The game's RNG is...|       0.0|[0.52950147670957...|        1.0|
# |  1.0|I didn't play Dar...|       0.0|[0.99483736565890...|        0.0|
# |  1.0|its a good game i...|       0.0|[0.66564265993111...|        0.0|
# |  1.0|                guud|       0.0|[0.57940247423050...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[53.  2.]
#  [ 2. 13.]]
# ========= 2023-05-24 08:31:50 =========
# +------+-----+---------+--------------------+
# |app_id|label|review_id|         review_text|
# +------+-----+---------+--------------------+
# |824600|  1.0|138886146|12/10 game, easil...|
# +------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|12/10 game, easil...|       0.0|[0.95018744362604...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[54.  2.]
#  [ 2. 13.]]
# ========= 2023-05-24 08:32:00 =========
# +------+-----+---------+--------------------+
# |app_id|label|review_id|         review_text|
# +------+-----+---------+--------------------+
# |824600|  1.0|138885902|The level design ...|
# |824600|  1.0|138885878|Literally soviet ...|
# +------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|The level design ...|       0.0|[0.92888082641719...|        0.0|
# |  1.0|Literally soviet ...|       0.0|[0.55977144074384...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[56.  2.]
#  [ 2. 13.]]
# ========= 2023-05-24 08:32:10 =========
# +------+-----+---------+--------------------+
# |app_id|label|review_id|         review_text|
# +------+-----+---------+--------------------+
# |824600|  1.0|138884833|       Anticommunist|
# |824600|  1.0|138884640|It's like Quake e...|
# +------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|       Anticommunist|       0.0|[0.57940247423050...|        0.0|
# |  1.0|It's like Quake e...|       0.0|[0.55556473621711...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
# Confusion matrix:
# [[58.  2.]
#  [ 2. 13.]]
# ========= 2023-05-24 08:32:40 =========
# +------+-----+---------+----------------+
# |app_id|label|review_id|     review_text|
# +------+-----+---------+----------------+
# |673750|  1.0|138885237|goofy bunny game|
# +------+-----+---------+----------------+
#
# +-----+----------------+----------+--------------------+-----------+
# |label|     review_text|prediction|         probability|label_index|
# +-----+----------------+----------+--------------------+-----------+
# |  1.0|goofy bunny game|       0.0|[0.58107589207678...|        0.0|
# +-----+----------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[59.  2.]
#  [ 2. 13.]]
# ========= 2023-05-24 08:33:10 =========
# +------+-----+---------+--------------------+
# |app_id|label|review_id|         review_text|
# +------+-----+---------+--------------------+
# |705040|  0.0|138885812|There's no amount...|
# |705040|  1.0|138884678|Very solid game a...|
# +------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  0.0|There's no amount...|       1.0|[0.12639033717798...|        1.0|
# |  1.0|Very solid game a...|       1.0|[0.44923165117471...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[59.  3.]
#  [ 2. 14.]]
# ========= 2023-05-24 08:34:40 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1268750|  1.0|138886522|            WDWADASD|
# |1268750|  1.0|138886492|Great game, hope ...|
# |1268750|  1.0|138886488|It's great that t...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|            WDWADASD|       0.0|[0.57940247423050...|        0.0|
# |  1.0|Great game, hope ...|       0.0|[0.70430579096460...|        0.0|
# |  1.0|It's great that t...|       0.0|[0.84786513256100...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[62.  3.]
#  [ 2. 14.]]
# ========= 2023-05-24 08:34:50 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1268750|  1.0|138886433|"M.I. Does the dy...|
# |1268750|  1.0|138886398|  I'm doing my part.|
# |1268750|  1.0|138886355|   I'M DOING MY PART|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|"M.I. Does the dy...|       0.0|[0.78432575059178...|        0.0|
# |  1.0|  I'm doing my part.|       0.0|[0.63348039999947...|        0.0|
# |  1.0|   I'M DOING MY PART|       0.0|[0.55878226957536...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[65.  3.]
#  [ 2. 14.]]
# ========= 2023-05-24 08:35:00 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1268750|  1.0|138886216|            it a fun|
# |1268750|  1.0|138886065|In the 23rd centu...|
# |1268750|  1.0|138885886|still bug's to wo...|
# |1268750|  1.0|138885874|THIS GAME HAS POT...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|            it a fun|       0.0|[0.58242776752717...|        0.0|
# |  1.0|In the 23rd centu...|       0.0|[0.97982494888873...|        0.0|
# |  1.0|still bug's to wo...|       0.0|[0.66270591370801...|        0.0|
# |  1.0|THIS GAME HAS POT...|       0.0|[0.76749767470535...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[69.  3.]
#  [ 2. 14.]]
# ========= 2023-05-24 08:36:40 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1934780|  1.0|138886042|well made third p...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|well made third p...|       1.0|[0.42335107911517...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[69.  4.]
#  [ 2. 14.]]
# ========= 2023-05-24 08:36:50 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1934780|  1.0|138885994|very well develop...|
# |1934780|  1.0|138885322|           Game Good|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|very well develop...|       0.0|[0.59049115396287...|        0.0|
# |  1.0|           Game Good|       0.0|[0.62895848282017...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[71.  4.]
#  [ 2. 14.]]
# ========= 2023-05-24 08:37:00 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |2370310|  1.0|138885571|Cozy little colon...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|Cozy little colon...|       0.0|[0.97793565673520...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[72.  4.]
#  [ 2. 14.]]
# ========= 2023-05-24 08:37:30 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |2248760|  1.0|138884766|                good|
# |2248760|  1.0|138884609|Fun game when you...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|                good|       0.0|[0.63362784686620...|        0.0|
# |  1.0|Fun game when you...|       0.0|[0.81052422318899...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[74.  4.]
#  [ 2. 14.]]
# ========= 2023-05-24 08:38:10 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1304930|  1.0|138886674|Your Little Nuts ...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|Your Little Nuts ...|       0.0|[0.72396842791481...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[75.  4.]
#  [ 2. 14.]]
# ========= 2023-05-24 08:38:20 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1304930|  1.0|138886387|The feeling of cl...|
# |1304930|  1.0|138886246|Even the tutorial...|
# |1304930|  1.0|138886162|Really good to pl...|
# +-------+-----+---------+--------------------+
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|The feeling of cl...|       1.0|[0.43403893509722...|        0.0|
# |  1.0|Even the tutorial...|       0.0|[0.84858423152974...|        0.0|
# |  1.0|Really good to pl...|       0.0|[0.72004039353363...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[77.  5.]
#  [ 2. 14.]]
# ========= 2023-05-24 08:38:30 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1304930|  1.0|138886138|Really good for E...|
# |1304930|  1.0|138886072|if you like being...|
# |1304930|  1.0|138886060|                ...,|
# |1304930|  1.0|138886044|- found syringe \...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|Really good for E...|       0.0|[0.64317698442693...|        0.0|
# |  1.0|if you like being...|       0.0|[0.61011529297252...|        0.0|
# |  1.0|                ...,|       0.0|[0.57940247423050...|        0.0|
# |  1.0|- found syringe \...|       0.0|[0.83920708535697...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[81.  5.]
#  [ 2. 14.]]
# ========= 2023-05-24 08:38:40 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1304930|  1.0|138886003|never been more b...|
# |1304930|  1.0|138885966|so scary but so f...|
# +-------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|never been more b...|       0.0|[0.61664092901365...|        0.0|
# |  1.0|so scary but so f...|       0.0|[0.64701565525735...|        0.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[83.  5.]
#  [ 2. 14.]]
# ========= 2023-05-24 08:39:00 =========
# +------+-----+---------+--------------------+
# |app_id|label|review_id|         review_text|
# +------+-----+---------+--------------------+
# |754890|  1.0|138886646|As a Myst/Riven f...|
# |754890|  1.0|138885617|   I like this game.|
# |754890|  0.0|138884661|I can't recommend...|
# +------+-----+---------+--------------------+
#
# +-----+--------------------+----------+--------------------+-----------+
# |label|         review_text|prediction|         probability|label_index|
# +-----+--------------------+----------+--------------------+-----------+
# |  1.0|As a Myst/Riven f...|       1.0|[5.35365667853632...|        0.0|
# |  1.0|   I like this game.|       0.0|[0.58933025576633...|        0.0|
# |  0.0|I can't recommend...|       0.0|[0.67126504037115...|        1.0|
# +-----+--------------------+----------+--------------------+-----------+
#
# Confusion matrix:
# [[84.  6.]
#  [ 3. 14.]]

# %%
ssc_t.stop()
# Out:
# ----- Stopping... this may take a few seconds -----
